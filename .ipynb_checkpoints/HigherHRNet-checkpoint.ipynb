# %%
import os
import sys
import argparse
import cv2
import time
import torch
from vidgear.gears import CamGear
import numpy as np

# Ensure this path is correct and points to the simple-HigherHRNet directory
sys.path.append(os.path.abspath('simple-HigherHRNet'))

# Import the required HRNet model classes and utilities
from SimpleHigherHRNet import SimpleHigherHRNet
from misc.visualization import draw_points, draw_skeleton, draw_points_and_skeleton, joints_dict, check_video_rotation
from misc.utils import find_person_id_associations

# %%
import cv2
import torch
from SimpleHigherHRNet import SimpleHigherHRNet
from misc.visualization import draw_points_and_skeleton, joints_dict
import matplotlib.pyplot as plt

# Load the image
image_path = "data/coco/images/test2017/000000000057.jpg"
image = cv2.imread(image_path)

# Check if the image was loaded correctly
if image is None:
    raise ValueError(f"Image at path '{image_path}' could not be loaded. Please check the path.")

print("Image loaded successfully.")

# Initialize the model
model = SimpleHigherHRNet(
    c=32,
    nof_joints=17,
    checkpoint_path="simple-HigherHRNet/weights/pose_higher_hrnet_w32_512.pth",
    resolution=512,
    return_bounding_boxes=False,
    max_nof_people=30,
    max_batch_size=16,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)

print("Model initialized successfully.")

# Perform pose estimation
joints = model.predict(image)

# Check if joints were detected
if len(joints) == 0:
    print("No joints detected.")
else:
    print(f"Detected joints for {len(joints)} people.")

# Draw the keypoints and skeleton on the image
if len(joints) > 0:
    skeleton = joints_dict()['coco']['skeleton']
    image = draw_points_and_skeleton(image, joints[0], skeleton, points_color_palette='gist_rainbow', skeleton_color_palette='jet')

# Display the image with keypoints and skeleton
# cv2.imshow("Pose Estimation", image)
plt.imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Image loaded successfully.
# C:\Users\rensl\Documents\Final_Project\simple-HigherHRNet\SimpleHigherHRNet.py:100: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=self.device)
# device: 'cuda' - 1 GPU(s) will be used
# Model initialized successfully.
# Detected joints for 1 people.

# %% [markdown]
# opening camera

# %%
import cv2
import torch
from SimpleHigherHRNet import SimpleHigherHRNet
from misc.visualization import draw_points_and_skeleton, joints_dict

# Initialize the model
model = SimpleHigherHRNet(
    c=32,
    nof_joints=17,
    checkpoint_path="simple-HigherHRNet/weights/pose_higher_hrnet_w32_512.pth",
    resolution=512,
    return_bounding_boxes=False,
    max_nof_people=30,
    max_batch_size=16,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)

print("Model initialized successfully.")

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

print("Camera opened successfully.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    joints = model.predict(frame)

    if len(joints) > 0:
        skeleton = joints_dict()['coco']['skeleton']
        frame = draw_points_and_skeleton(frame, joints[0], skeleton, points_color_palette='gist_rainbow', skeleton_color_palette='jet')

    cv2.imshow("Pose Estimation", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# device: 'cuda' - 1 GPU(s) will be used
# Model initialized successfully.
# Camera opened successfully.

# %%
import cv2
import numpy as np
import os
import torch
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from SimpleHigherHRNet import SimpleHigherHRNet

# Adjust this to your actual base path
base_path = "data/coco"
image_folder = os.path.join(base_path, "images/val2017")

# Check if the image folder exists
if not os.path.exists(image_folder):
    raise FileNotFoundError(f"Image folder not found: {image_folder}")

# Initialize HigherHRNet model
model = SimpleHigherHRNet(
    c=32,
    nof_joints=17,
    checkpoint_path="simple-HigherHRNet/weights/pose_higher_hrnet_w32_512.pth",
    resolution=512,
    return_bounding_boxes=False,
    max_nof_people=30,
    max_batch_size=16,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)

def process_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to read image: {image_path}")
        return None
    image_height, image_width, _ = image.shape
    joints = model.predict(image)
    
    if len(joints) == 0:
        return None

    # We'll just use the first person detected for simplicity
    person_joints = joints[0]
    
    coco_keypoints = []
    x_coords = []
    y_coords = []
    for x, y, confidence in person_joints:
        x_pixel = int(x * image_width)
        y_pixel = int(y * image_height)
        coco_keypoints.extend([x_pixel, y_pixel, 2 if confidence > 0.1 else 0])
        if confidence > 0.1:
            x_coords.append(x_pixel)
            y_coords.append(y_pixel)
    
    if x_coords and y_coords:
        x_min, x_max = min(x_coords), max(x_coords)
        y_min, y_max = min(y_coords), max(y_coords)
        width = x_max - x_min
        height = y_max - y_min
        bbox = [x_min, y_min, width, height]
    else:
        bbox = [0, 0, 0, 0]
    
    return coco_keypoints, bbox if len(coco_keypoints) == 51 else None

# Process COCO dataset
coco = COCO(os.path.join(base_path, 'annotations/person_keypoints_val2017.json'))
results = []
processed_count = 0
skipped_count = 0

for img_id in coco.getImgIds():  # Limiting to the first 50 images
    img_info = coco.loadImgs(img_id)[0]
    image_path = os.path.join(image_folder, img_info['file_name'])
    if os.path.exists(image_path):
        print(f"Processing image: {image_path}")
        result = process_image(image_path)
        if result:
            keypoints, bbox = result
            result = {
                'image_id': img_id,
                'category_id': 1,  # person category
                'keypoints': keypoints,
                'bbox': bbox,
                'score': np.mean([kp for i, kp in enumerate(keypoints) if i % 3 == 2])  # average confidence
            }
            results.append(result)
            processed_count += 1
    else:
        print(f"Image not found: {image_path}")
        skipped_count += 1

print(f"Total images processed: {processed_count}")
print(f"Total images skipped (not found): {skipped_count}")

# Print a sample result
if results:
    print("Sample result:")
    print(results[0])
    print("Number of keypoints:", len(results[0]['keypoints']))
    print("First few keypoints:", results[0]['keypoints'][:6])
    print("Bounding box:", results[0]['bbox'])

# Evaluate
if results:
    coco_dt = coco.loadRes(results)
    coco_eval = COCOeval(coco, coco_dt, 'keypoints')
    coco_eval.params.imgIds = [r['image_id'] for r in results]  # Only evaluate on processed images
    coco_eval.evaluate()
    coco_eval.accumulate()
    coco_eval.summarize()
    print(f"AP: {coco_eval.stats[0]}")
    print(f"AP.5: {coco_eval.stats[1]}")
    print(f"AP.75: {coco_eval.stats[2]}")
    print(f"AP (M): {coco_eval.stats[3]}")
    print(f"AP (L): {coco_eval.stats[4]}")
else:
    print("No results to evaluate. Check if any images were successfully processed.")
# Out:
# device: 'cuda' - 1 GPU(s) will be used
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!
# Processing image: data/coco\images/val2017\000000397133.jpg
# Processing image: data/coco\images/val2017\000000037777.jpg
# Processing image: data/coco\images/val2017\000000252219.jpg
# Processing image: data/coco\images/val2017\000000087038.jpg
# Processing image: data/coco\images/val2017\000000174482.jpg
# Processing image: data/coco\images/val2017\000000403385.jpg
# Processing image: data/coco\images/val2017\000000006818.jpg
# Processing image: data/coco\images/val2017\000000480985.jpg
# Processing image: data/coco\images/val2017\000000458054.jpg
# Processing image: data/coco\images/val2017\000000331352.jpg
# Processing image: data/coco\images/val2017\000000296649.jpg
# Processing image: data/coco\images/val2017\000000386912.jpg
# Processing image: data/coco\images/val2017\000000502136.jpg
# Processing image: data/coco\images/val2017\000000491497.jpg
# Processing image: data/coco\images/val2017\000000184791.jpg
# Processing image: data/coco\images/val2017\000000348881.jpg
# Processing image: data/coco\images/val2017\000000289393.jpg
# Processing image: data/coco\images/val2017\000000522713.jpg
# Processing image: data/coco\images/val2017\000000181666.jpg
# Processing image: data/coco\images/val2017\000000017627.jpg
# Processing image: data/coco\images/val2017\000000143931.jpg
# Processing image: data/coco\images/val2017\000000303818.jpg
# Processing image: data/coco\images/val2017\000000463730.jpg
# Processing image: data/coco\images/val2017\000000460347.jpg
# Processing image: data/coco\images/val2017\000000322864.jpg
# Processing image: data/coco\images/val2017\000000226111.jpg
# Processing image: data/coco\images/val2017\000000153299.jpg
# Processing image: data/coco\images/val2017\000000308394.jpg
# Processing image: data/coco\images/val2017\000000456496.jpg
# Processing image: data/coco\images/val2017\000000058636.jpg
# Processing image: data/coco\images/val2017\000000041888.jpg
# Processing image: data/coco\images/val2017\000000184321.jpg
# Processing image: data/coco\images/val2017\000000565778.jpg
# Processing image: data/coco\images/val2017\000000297343.jpg
# Processing image: data/coco\images/val2017\000000336587.jpg
# Processing image: data/coco\images/val2017\000000122745.jpg
# Processing image: data/coco\images/val2017\000000219578.jpg
# Processing image: data/coco\images/val2017\000000555705.jpg
# Processing image: data/coco\images/val2017\000000443303.jpg
# Processing image: data/coco\images/val2017\000000500663.jpg
# Processing image: data/coco\images/val2017\000000418281.jpg
# Processing image: data/coco\images/val2017\000000025560.jpg
# Processing image: data/coco\images/val2017\000000403817.jpg
# Processing image: data/coco\images/val2017\000000085329.jpg
# Processing image: data/coco\images/val2017\000000329323.jpg
# Processing image: data/coco\images/val2017\000000239274.jpg
# Processing image: data/coco\images/val2017\000000286994.jpg
# Processing image: data/coco\images/val2017\000000511321.jpg
# Processing image: data/coco\images/val2017\000000314294.jpg
# Processing image: data/coco\images/val2017\000000233771.jpg
# Processing image: data/coco\images/val2017\000000475779.jpg
# Processing image: data/coco\images/val2017\000000301867.jpg
# Processing image: data/coco\images/val2017\000000312421.jpg
# Processing image: data/coco\images/val2017\000000185250.jpg
# Processing image: data/coco\images/val2017\000000356427.jpg
# Processing image: data/coco\images/val2017\000000572517.jpg
# Processing image: data/coco\images/val2017\000000270244.jpg
# Processing image: data/coco\images/val2017\000000516316.jpg
# Processing image: data/coco\images/val2017\000000125211.jpg
# Processing image: data/coco\images/val2017\000000562121.jpg
# Processing image: data/coco\images/val2017\000000360661.jpg
# Processing image: data/coco\images/val2017\000000016228.jpg
# Processing image: data/coco\images/val2017\000000382088.jpg
# Processing image: data/coco\images/val2017\000000266409.jpg
# Processing image: data/coco\images/val2017\000000430961.jpg
# Processing image: data/coco\images/val2017\000000080671.jpg
# Processing image: data/coco\images/val2017\000000577539.jpg
# Processing image: data/coco\images/val2017\000000104612.jpg
# Processing image: data/coco\images/val2017\000000476258.jpg
# Processing image: data/coco\images/val2017\000000448365.jpg
# Processing image: data/coco\images/val2017\000000035197.jpg
# Processing image: data/coco\images/val2017\000000349860.jpg
# Processing image: data/coco\images/val2017\000000180135.jpg
# Processing image: data/coco\images/val2017\000000486438.jpg
# Processing image: data/coco\images/val2017\000000400573.jpg
# Processing image: data/coco\images/val2017\000000109798.jpg
# Processing image: data/coco\images/val2017\000000370677.jpg
# Processing image: data/coco\images/val2017\000000238866.jpg
# Processing image: data/coco\images/val2017\000000369370.jpg
# Processing image: data/coco\images/val2017\000000502737.jpg
# Processing image: data/coco\images/val2017\000000515579.jpg
# Processing image: data/coco\images/val2017\000000515445.jpg
# Processing image: data/coco\images/val2017\000000173383.jpg
# Processing image: data/coco\images/val2017\000000438862.jpg
# Processing image: data/coco\images/val2017\000000180560.jpg
# Processing image: data/coco\images/val2017\000000347693.jpg
# Processing image: data/coco\images/val2017\000000039956.jpg
# Processing image: data/coco\images/val2017\000000321214.jpg
# Processing image: data/coco\images/val2017\000000474028.jpg
# Processing image: data/coco\images/val2017\000000066523.jpg
# Processing image: data/coco\images/val2017\000000355257.jpg
# Processing image: data/coco\images/val2017\000000142092.jpg
# Processing image: data/coco\images/val2017\000000063154.jpg
# Processing image: data/coco\images/val2017\000000199551.jpg
# Processing image: data/coco\images/val2017\000000239347.jpg
# Processing image: data/coco\images/val2017\000000514508.jpg
# Processing image: data/coco\images/val2017\000000473237.jpg
# Processing image: data/coco\images/val2017\000000228144.jpg
# Processing image: data/coco\images/val2017\000000206027.jpg
# Processing image: data/coco\images/val2017\000000078915.jpg
# Processing image: data/coco\images/val2017\000000551215.jpg
# Processing image: data/coco\images/val2017\000000544519.jpg
# Processing image: data/coco\images/val2017\000000096493.jpg
# Processing image: data/coco\images/val2017\000000023899.jpg
# Processing image: data/coco\images/val2017\000000340175.jpg
# Processing image: data/coco\images/val2017\000000578500.jpg
# Processing image: data/coco\images/val2017\000000366141.jpg
# Processing image: data/coco\images/val2017\000000057597.jpg
# Processing image: data/coco\images/val2017\000000559842.jpg
# Processing image: data/coco\images/val2017\000000434230.jpg
# Processing image: data/coco\images/val2017\000000428454.jpg
# Processing image: data/coco\images/val2017\000000399462.jpg
# Processing image: data/coco\images/val2017\000000261061.jpg
# Processing image: data/coco\images/val2017\000000168330.jpg
# Processing image: data/coco\images/val2017\000000383384.jpg
# Processing image: data/coco\images/val2017\000000342006.jpg
# Processing image: data/coco\images/val2017\000000217285.jpg
# Processing image: data/coco\images/val2017\000000236412.jpg
# Processing image: data/coco\images/val2017\000000524456.jpg
# Processing image: data/coco\images/val2017\000000153343.jpg
# Processing image: data/coco\images/val2017\000000095786.jpg
# Processing image: data/coco\images/val2017\000000326541.jpg
# Processing image: data/coco\images/val2017\000000213086.jpg
# Processing image: data/coco\images/val2017\000000231339.jpg
# Processing image: data/coco\images/val2017\000000508730.jpg
# Processing image: data/coco\images/val2017\000000550426.jpg
# Processing image: data/coco\images/val2017\000000368294.jpg
# Processing image: data/coco\images/val2017\000000171190.jpg
# Processing image: data/coco\images/val2017\000000301135.jpg
# Processing image: data/coco\images/val2017\000000580294.jpg
# Processing image: data/coco\images/val2017\000000494869.jpg
# Processing image: data/coco\images/val2017\000000033638.jpg
# Processing image: data/coco\images/val2017\000000329219.jpg
# Processing image: data/coco\images/val2017\000000034873.jpg
# Processing image: data/coco\images/val2017\000000186980.jpg
# Processing image: data/coco\images/val2017\000000127182.jpg
# Processing image: data/coco\images/val2017\000000356387.jpg
# Processing image: data/coco\images/val2017\000000367680.jpg
# Processing image: data/coco\images/val2017\000000263796.jpg
# Processing image: data/coco\images/val2017\000000117425.jpg
# Processing image: data/coco\images/val2017\000000365387.jpg
# Processing image: data/coco\images/val2017\000000487583.jpg
# Processing image: data/coco\images/val2017\000000504711.jpg
# Processing image: data/coco\images/val2017\000000363840.jpg
# Processing image: data/coco\images/val2017\000000214720.jpg
# Processing image: data/coco\images/val2017\000000379453.jpg
# Processing image: data/coco\images/val2017\000000311295.jpg
# Processing image: data/coco\images/val2017\000000029393.jpg
# Processing image: data/coco\images/val2017\000000278848.jpg
# Processing image: data/coco\images/val2017\000000166391.jpg
# Processing image: data/coco\images/val2017\000000048153.jpg
# Processing image: data/coco\images/val2017\000000459153.jpg
# Processing image: data/coco\images/val2017\000000295713.jpg
# Processing image: data/coco\images/val2017\000000223130.jpg
# Processing image: data/coco\images/val2017\000000273132.jpg
# Processing image: data/coco\images/val2017\000000198960.jpg
# Processing image: data/coco\images/val2017\000000344059.jpg
# Processing image: data/coco\images/val2017\000000410428.jpg
# Processing image: data/coco\images/val2017\000000087875.jpg
# Processing image: data/coco\images/val2017\000000450758.jpg
# Processing image: data/coco\images/val2017\000000458790.jpg
# Processing image: data/coco\images/val2017\000000460160.jpg
# Processing image: data/coco\images/val2017\000000458109.jpg
# Processing image: data/coco\images/val2017\000000030675.jpg
# Processing image: data/coco\images/val2017\000000566524.jpg
# Processing image: data/coco\images/val2017\000000338428.jpg
# Processing image: data/coco\images/val2017\000000545826.jpg
# Processing image: data/coco\images/val2017\000000166277.jpg
# Processing image: data/coco\images/val2017\000000269314.jpg
# Processing image: data/coco\images/val2017\000000476415.jpg
# Processing image: data/coco\images/val2017\000000292082.jpg
# Processing image: data/coco\images/val2017\000000360137.jpg
# Processing image: data/coco\images/val2017\000000122046.jpg
# Processing image: data/coco\images/val2017\000000352684.jpg
# Processing image: data/coco\images/val2017\000000512836.jpg
# Processing image: data/coco\images/val2017\000000008021.jpg
# Processing image: data/coco\images/val2017\000000107226.jpg
# Processing image: data/coco\images/val2017\000000084477.jpg
# Processing image: data/coco\images/val2017\000000562243.jpg
# Processing image: data/coco\images/val2017\000000181859.jpg
# Processing image: data/coco\images/val2017\000000177015.jpg
# Processing image: data/coco\images/val2017\000000292236.jpg
# Processing image: data/coco\images/val2017\000000121506.jpg
# Processing image: data/coco\images/val2017\000000288042.jpg
# Processing image: data/coco\images/val2017\000000453860.jpg
# Processing image: data/coco\images/val2017\000000500257.jpg
# Processing image: data/coco\images/val2017\000000113403.jpg
# Processing image: data/coco\images/val2017\000000125062.jpg
# Processing image: data/coco\images/val2017\000000375015.jpg
# Processing image: data/coco\images/val2017\000000334719.jpg
# Processing image: data/coco\images/val2017\000000134112.jpg
# Processing image: data/coco\images/val2017\000000283520.jpg
# Processing image: data/coco\images/val2017\000000031269.jpg
# Processing image: data/coco\images/val2017\000000319721.jpg
# Processing image: data/coco\images/val2017\000000165351.jpg
# Processing image: data/coco\images/val2017\000000347265.jpg
# Processing image: data/coco\images/val2017\000000414170.jpg
# Processing image: data/coco\images/val2017\000000231508.jpg
# Processing image: data/coco\images/val2017\000000389381.jpg
# Processing image: data/coco\images/val2017\000000118921.jpg
# Processing image: data/coco\images/val2017\000000021503.jpg
# Processing image: data/coco\images/val2017\000000000785.jpg
# Processing image: data/coco\images/val2017\000000300842.jpg
# Processing image: data/coco\images/val2017\000000105014.jpg
# Processing image: data/coco\images/val2017\000000261982.jpg
# Processing image: data/coco\images/val2017\000000034205.jpg
# Processing image: data/coco\images/val2017\000000099242.jpg
# Processing image: data/coco\images/val2017\000000314709.jpg
# Processing image: data/coco\images/val2017\000000460494.jpg
# Processing image: data/coco\images/val2017\000000339442.jpg
# Processing image: data/coco\images/val2017\000000541055.jpg
# Processing image: data/coco\images/val2017\000000409475.jpg
# Processing image: data/coco\images/val2017\000000464786.jpg
# Processing image: data/coco\images/val2017\000000378605.jpg
# Processing image: data/coco\images/val2017\000000331817.jpg
# Processing image: data/coco\images/val2017\000000218091.jpg
# Processing image: data/coco\images/val2017\000000578545.jpg
# Processing image: data/coco\images/val2017\000000363207.jpg
# Processing image: data/coco\images/val2017\000000372577.jpg
# Processing image: data/coco\images/val2017\000000212166.jpg
# Processing image: data/coco\images/val2017\000000172571.jpg
# Processing image: data/coco\images/val2017\000000294831.jpg
# Processing image: data/coco\images/val2017\000000084431.jpg
# Processing image: data/coco\images/val2017\000000323355.jpg
# Processing image: data/coco\images/val2017\000000355325.jpg
# Processing image: data/coco\images/val2017\000000100582.jpg
# Processing image: data/coco\images/val2017\000000555412.jpg
# Processing image: data/coco\images/val2017\000000004495.jpg
# Processing image: data/coco\images/val2017\000000009483.jpg
# Processing image: data/coco\images/val2017\000000326082.jpg
# Processing image: data/coco\images/val2017\000000398237.jpg
# Processing image: data/coco\images/val2017\000000507223.jpg
# Processing image: data/coco\images/val2017\000000031050.jpg
# Processing image: data/coco\images/val2017\000000239537.jpg
# Processing image: data/coco\images/val2017\000000340930.jpg
# Processing image: data/coco\images/val2017\000000011813.jpg
# Processing image: data/coco\images/val2017\000000281414.jpg
# Processing image: data/coco\images/val2017\000000537991.jpg
# Processing image: data/coco\images/val2017\000000284282.jpg
# Processing image: data/coco\images/val2017\000000321333.jpg
# Processing image: data/coco\images/val2017\000000521282.jpg
# Processing image: data/coco\images/val2017\000000108026.jpg
# Processing image: data/coco\images/val2017\000000243204.jpg
# Processing image: data/coco\images/val2017\000000177935.jpg
# Processing image: data/coco\images/val2017\000000038829.jpg
# Processing image: data/coco\images/val2017\000000397327.jpg
# Processing image: data/coco\images/val2017\000000501523.jpg
# Processing image: data/coco\images/val2017\000000555050.jpg
# Processing image: data/coco\images/val2017\000000376442.jpg
# Processing image: data/coco\images/val2017\000000187243.jpg
# Processing image: data/coco\images/val2017\000000356347.jpg
# Processing image: data/coco\images/val2017\000000293044.jpg
# Processing image: data/coco\images/val2017\000000560279.jpg
# Processing image: data/coco\images/val2017\000000042276.jpg
# Processing image: data/coco\images/val2017\000000534827.jpg
# Processing image: data/coco\images/val2017\000000190756.jpg
# Processing image: data/coco\images/val2017\000000482917.jpg
# Processing image: data/coco\images/val2017\000000300659.jpg
# Processing image: data/coco\images/val2017\000000199977.jpg
# Processing image: data/coco\images/val2017\000000442480.jpg
# Processing image: data/coco\images/val2017\000000384350.jpg
# Processing image: data/coco\images/val2017\000000383621.jpg
# Processing image: data/coco\images/val2017\000000189828.jpg
# Processing image: data/coco\images/val2017\000000412894.jpg
# Processing image: data/coco\images/val2017\000000537153.jpg
# Processing image: data/coco\images/val2017\000000361103.jpg
# Processing image: data/coco\images/val2017\000000392722.jpg
# Processing image: data/coco\images/val2017\000000338560.jpg
# Processing image: data/coco\images/val2017\000000264535.jpg
# Processing image: data/coco\images/val2017\000000295231.jpg
# Processing image: data/coco\images/val2017\000000154947.jpg
# Processing image: data/coco\images/val2017\000000212559.jpg
# Processing image: data/coco\images/val2017\000000458755.jpg
# Processing image: data/coco\images/val2017\000000104782.jpg
# Processing image: data/coco\images/val2017\000000315257.jpg
# Processing image: data/coco\images/val2017\000000130599.jpg
# Processing image: data/coco\images/val2017\000000227187.jpg
# Processing image: data/coco\images/val2017\000000151662.jpg
# Processing image: data/coco\images/val2017\000000461275.jpg
# Processing image: data/coco\images/val2017\000000523811.jpg
# Processing image: data/coco\images/val2017\000000456559.jpg
# Processing image: data/coco\images/val2017\000000101068.jpg
# Processing image: data/coco\images/val2017\000000140640.jpg
# Processing image: data/coco\images/val2017\000000516708.jpg
# Processing image: data/coco\images/val2017\000000544605.jpg
# Processing image: data/coco\images/val2017\000000385190.jpg
# Processing image: data/coco\images/val2017\000000338986.jpg
# Processing image: data/coco\images/val2017\000000053994.jpg
# Processing image: data/coco\images/val2017\000000061171.jpg
# Processing image: data/coco\images/val2017\000000314034.jpg
# Processing image: data/coco\images/val2017\000000291490.jpg
# Processing image: data/coco\images/val2017\000000152740.jpg
# Processing image: data/coco\images/val2017\000000024919.jpg
# Processing image: data/coco\images/val2017\000000079837.jpg
# Processing image: data/coco\images/val2017\000000021903.jpg
# Processing image: data/coco\images/val2017\000000564133.jpg
# Processing image: data/coco\images/val2017\000000337055.jpg
# Processing image: data/coco\images/val2017\000000110638.jpg
# Processing image: data/coco\images/val2017\000000034139.jpg
# Processing image: data/coco\images/val2017\000000080340.jpg
# Processing image: data/coco\images/val2017\000000083113.jpg
# Processing image: data/coco\images/val2017\000000173033.jpg
# Processing image: data/coco\images/val2017\000000255664.jpg
# Processing image: data/coco\images/val2017\000000072813.jpg
# Processing image: data/coco\images/val2017\000000545129.jpg
# Processing image: data/coco\images/val2017\000000546011.jpg
# Processing image: data/coco\images/val2017\000000121031.jpg
# Processing image: data/coco\images/val2017\000000172547.jpg
# Processing image: data/coco\images/val2017\000000369081.jpg
# Processing image: data/coco\images/val2017\000000509131.jpg
# Processing image: data/coco\images/val2017\000000578922.jpg
# Processing image: data/coco\images/val2017\000000464089.jpg
# Processing image: data/coco\images/val2017\000000453708.jpg
# Processing image: data/coco\images/val2017\000000177714.jpg
# Processing image: data/coco\images/val2017\000000459887.jpg
# Processing image: data/coco\images/val2017\000000155179.jpg
# Processing image: data/coco\images/val2017\000000261116.jpg
# Processing image: data/coco\images/val2017\000000396274.jpg
# Processing image: data/coco\images/val2017\000000029640.jpg
# Processing image: data/coco\images/val2017\000000141328.jpg
# Processing image: data/coco\images/val2017\000000308430.jpg
# Processing image: data/coco\images/val2017\000000043314.jpg
# Processing image: data/coco\images/val2017\000000273715.jpg
# Processing image: data/coco\images/val2017\000000456303.jpg
# Processing image: data/coco\images/val2017\000000406611.jpg
# Processing image: data/coco\images/val2017\000000475064.jpg
# Processing image: data/coco\images/val2017\000000466567.jpg
# Processing image: data/coco\images/val2017\000000137246.jpg
# Processing image: data/coco\images/val2017\000000015079.jpg
# Processing image: data/coco\images/val2017\000000296284.jpg
# Processing image: data/coco\images/val2017\000000226147.jpg
# Processing image: data/coco\images/val2017\000000226903.jpg
# Processing image: data/coco\images/val2017\000000127517.jpg
# Processing image: data/coco\images/val2017\000000162092.jpg
# Processing image: data/coco\images/val2017\000000131379.jpg
# Processing image: data/coco\images/val2017\000000366611.jpg
# Processing image: data/coco\images/val2017\000000263969.jpg
# Processing image: data/coco\images/val2017\000000551439.jpg
# Processing image: data/coco\images/val2017\000000474167.jpg
# Processing image: data/coco\images/val2017\000000159458.jpg
# Processing image: data/coco\images/val2017\000000554735.jpg
# Processing image: data/coco\images/val2017\000000099428.jpg
# Processing image: data/coco\images/val2017\000000386352.jpg
# Processing image: data/coco\images/val2017\000000173004.jpg
# Processing image: data/coco\images/val2017\000000311394.jpg
# Processing image: data/coco\images/val2017\000000578489.jpg
# Processing image: data/coco\images/val2017\000000189310.jpg
# Processing image: data/coco\images/val2017\000000491366.jpg
# Processing image: data/coco\images/val2017\000000448076.jpg
# Processing image: data/coco\images/val2017\000000293804.jpg
# Processing image: data/coco\images/val2017\000000312237.jpg
# Processing image: data/coco\images/val2017\000000221291.jpg
# Processing image: data/coco\images/val2017\000000141821.jpg
# Processing image: data/coco\images/val2017\000000410650.jpg
# Processing image: data/coco\images/val2017\000000199310.jpg
# Processing image: data/coco\images/val2017\000000323151.jpg
# Processing image: data/coco\images/val2017\000000089648.jpg
# Processing image: data/coco\images/val2017\000000219283.jpg
# Processing image: data/coco\images/val2017\000000471869.jpg
# Processing image: data/coco\images/val2017\000000520264.jpg
# Processing image: data/coco\images/val2017\000000111179.jpg
# Processing image: data/coco\images/val2017\000000151000.jpg
# Processing image: data/coco\images/val2017\000000100624.jpg
# Processing image: data/coco\images/val2017\000000332570.jpg
# Processing image: data/coco\images/val2017\000000057238.jpg
# Processing image: data/coco\images/val2017\000000502732.jpg
# Processing image: data/coco\images/val2017\000000135561.jpg
# Processing image: data/coco\images/val2017\000000008277.jpg
# Processing image: data/coco\images/val2017\000000173044.jpg
# Processing image: data/coco\images/val2017\000000168458.jpg
# Processing image: data/coco\images/val2017\000000512194.jpg
# Processing image: data/coco\images/val2017\000000370042.jpg
# Processing image: data/coco\images/val2017\000000189436.jpg
# Processing image: data/coco\images/val2017\000000533958.jpg
# Processing image: data/coco\images/val2017\000000117645.jpg
# Processing image: data/coco\images/val2017\000000221708.jpg
# Processing image: data/coco\images/val2017\000000202228.jpg
# Processing image: data/coco\images/val2017\000000403565.jpg
# Processing image: data/coco\images/val2017\000000211042.jpg
# Processing image: data/coco\images/val2017\000000492878.jpg
# Processing image: data/coco\images/val2017\000000441586.jpg
# Processing image: data/coco\images/val2017\000000547816.jpg
# Processing image: data/coco\images/val2017\000000306733.jpg
# Processing image: data/coco\images/val2017\000000530099.jpg
# Processing image: data/coco\images/val2017\000000312278.jpg
# Processing image: data/coco\images/val2017\000000097679.jpg
# Processing image: data/coco\images/val2017\000000564127.jpg
# Processing image: data/coco\images/val2017\000000251065.jpg
# Processing image: data/coco\images/val2017\000000003845.jpg
# Processing image: data/coco\images/val2017\000000138819.jpg
# Processing image: data/coco\images/val2017\000000205834.jpg
# Processing image: data/coco\images/val2017\000000348708.jpg
# Processing image: data/coco\images/val2017\000000166521.jpg
# Processing image: data/coco\images/val2017\000000485802.jpg
# Processing image: data/coco\images/val2017\000000099054.jpg
# Processing image: data/coco\images/val2017\000000022969.jpg
# Processing image: data/coco\images/val2017\000000570539.jpg
# Processing image: data/coco\images/val2017\000000278353.jpg
# Processing image: data/coco\images/val2017\000000158548.jpg
# Processing image: data/coco\images/val2017\000000461405.jpg
# Processing image: data/coco\images/val2017\000000176606.jpg
# Processing image: data/coco\images/val2017\000000044699.jpg
# Processing image: data/coco\images/val2017\000000559956.jpg
# Processing image: data/coco\images/val2017\000000268996.jpg
# Processing image: data/coco\images/val2017\000000011197.jpg
# Processing image: data/coco\images/val2017\000000483667.jpg
# Processing image: data/coco\images/val2017\000000448810.jpg
# Processing image: data/coco\images/val2017\000000000724.jpg
# Processing image: data/coco\images/val2017\000000051961.jpg
# Processing image: data/coco\images/val2017\000000375278.jpg
# Processing image: data/coco\images/val2017\000000302165.jpg
# Processing image: data/coco\images/val2017\000000131131.jpg
# Processing image: data/coco\images/val2017\000000098839.jpg
# Processing image: data/coco\images/val2017\000000402992.jpg
# Processing image: data/coco\images/val2017\000000465675.jpg
# Processing image: data/coco\images/val2017\000000240754.jpg
# Processing image: data/coco\images/val2017\000000021167.jpg
# Processing image: data/coco\images/val2017\000000148730.jpg
# Processing image: data/coco\images/val2017\000000384468.jpg
# Processing image: data/coco\images/val2017\000000253742.jpg
# Processing image: data/coco\images/val2017\000000186873.jpg
# Processing image: data/coco\images/val2017\000000082180.jpg
# Processing image: data/coco\images/val2017\000000446522.jpg
# Processing image: data/coco\images/val2017\000000552902.jpg
# Processing image: data/coco\images/val2017\000000125405.jpg
# Processing image: data/coco\images/val2017\000000110211.jpg
# Processing image: data/coco\images/val2017\000000016010.jpg
# Processing image: data/coco\images/val2017\000000064462.jpg
# Processing image: data/coco\images/val2017\000000314182.jpg
# Processing image: data/coco\images/val2017\000000248980.jpg
# Processing image: data/coco\images/val2017\000000068387.jpg
# Processing image: data/coco\images/val2017\000000429281.jpg
# Processing image: data/coco\images/val2017\000000345466.jpg
# Processing image: data/coco\images/val2017\000000352900.jpg
# Processing image: data/coco\images/val2017\000000118367.jpg
# Processing image: data/coco\images/val2017\000000113235.jpg
# Processing image: data/coco\images/val2017\000000311303.jpg
# Processing image: data/coco\images/val2017\000000163640.jpg
# Processing image: data/coco\images/val2017\000000370999.jpg
# Processing image: data/coco\images/val2017\000000001490.jpg
# Processing image: data/coco\images/val2017\000000329456.jpg
# Processing image: data/coco\images/val2017\000000570471.jpg
# Processing image: data/coco\images/val2017\000000088269.jpg
# Processing image: data/coco\images/val2017\000000260470.jpg
# Processing image: data/coco\images/val2017\000000193494.jpg
# Processing image: data/coco\images/val2017\000000252776.jpg
# Processing image: data/coco\images/val2017\000000201072.jpg
# Processing image: data/coco\images/val2017\000000018150.jpg
# Processing image: data/coco\images/val2017\000000337498.jpg
# Processing image: data/coco\images/val2017\000000521405.jpg
# Processing image: data/coco\images/val2017\000000518770.jpg
# Processing image: data/coco\images/val2017\000000201646.jpg
# Processing image: data/coco\images/val2017\000000036936.jpg
# Processing image: data/coco\images/val2017\000000059044.jpg
# Processing image: data/coco\images/val2017\000000172946.jpg
# Processing image: data/coco\images/val2017\000000234607.jpg
# Processing image: data/coco\images/val2017\000000532690.jpg
# Processing image: data/coco\images/val2017\000000323895.jpg
# Processing image: data/coco\images/val2017\000000384670.jpg
# Processing image: data/coco\images/val2017\000000050326.jpg
# Processing image: data/coco\images/val2017\000000205542.jpg
# Processing image: data/coco\images/val2017\000000217957.jpg
# Processing image: data/coco\images/val2017\000000162035.jpg
# Processing image: data/coco\images/val2017\000000415727.jpg
# Processing image: data/coco\images/val2017\000000046252.jpg
# Processing image: data/coco\images/val2017\000000182021.jpg
# Processing image: data/coco\images/val2017\000000231747.jpg
# Processing image: data/coco\images/val2017\000000090284.jpg
# Processing image: data/coco\images/val2017\000000286553.jpg
# Processing image: data/coco\images/val2017\000000488736.jpg
# Processing image: data/coco\images/val2017\000000063602.jpg
# Processing image: data/coco\images/val2017\000000383386.jpg
# Processing image: data/coco\images/val2017\000000450686.jpg
# Processing image: data/coco\images/val2017\000000005060.jpg
# Processing image: data/coco\images/val2017\000000286523.jpg
# Processing image: data/coco\images/val2017\000000120420.jpg
# Processing image: data/coco\images/val2017\000000579655.jpg
# Processing image: data/coco\images/val2017\000000117908.jpg
# Processing image: data/coco\images/val2017\000000550322.jpg
# Processing image: data/coco\images/val2017\000000322844.jpg
# Processing image: data/coco\images/val2017\000000218362.jpg
# Processing image: data/coco\images/val2017\000000213224.jpg
# Processing image: data/coco\images/val2017\000000223747.jpg
# Processing image: data/coco\images/val2017\000000297578.jpg
# Processing image: data/coco\images/val2017\000000458992.jpg
# Processing image: data/coco\images/val2017\000000078266.jpg
# Processing image: data/coco\images/val2017\000000164602.jpg
# Processing image: data/coco\images/val2017\000000440475.jpg
# Processing image: data/coco\images/val2017\000000101762.jpg
# Processing image: data/coco\images/val2017\000000557501.jpg
# Processing image: data/coco\images/val2017\000000203317.jpg
# Processing image: data/coco\images/val2017\000000368940.jpg
# Processing image: data/coco\images/val2017\000000569917.jpg
# Processing image: data/coco\images/val2017\000000144798.jpg
# Processing image: data/coco\images/val2017\000000284623.jpg
# Processing image: data/coco\images/val2017\000000520301.jpg
# Processing image: data/coco\images/val2017\000000127987.jpg
# Processing image: data/coco\images/val2017\000000063740.jpg
# Processing image: data/coco\images/val2017\000000036494.jpg
# Processing image: data/coco\images/val2017\000000210032.jpg
# Processing image: data/coco\images/val2017\000000488270.jpg
# Processing image: data/coco\images/val2017\000000067180.jpg
# Processing image: data/coco\images/val2017\000000281179.jpg
# Processing image: data/coco\images/val2017\000000064359.jpg
# Processing image: data/coco\images/val2017\000000126226.jpg
# Processing image: data/coco\images/val2017\000000190923.jpg
# Processing image: data/coco\images/val2017\000000150265.jpg
# Processing image: data/coco\images/val2017\000000216739.jpg
# Processing image: data/coco\images/val2017\000000038048.jpg
# Processing image: data/coco\images/val2017\000000354829.jpg
# Processing image: data/coco\images/val2017\000000525155.jpg
# Processing image: data/coco\images/val2017\000000163314.jpg
# Processing image: data/coco\images/val2017\000000259571.jpg
# Processing image: data/coco\images/val2017\000000561679.jpg
# Processing image: data/coco\images/val2017\000000236166.jpg
# Processing image: data/coco\images/val2017\000000153529.jpg
# Processing image: data/coco\images/val2017\000000473015.jpg
# Processing image: data/coco\images/val2017\000000379800.jpg
# Processing image: data/coco\images/val2017\000000253835.jpg
# Processing image: data/coco\images/val2017\000000034071.jpg
# Processing image: data/coco\images/val2017\000000036861.jpg
# Processing image: data/coco\images/val2017\000000569565.jpg
# Processing image: data/coco\images/val2017\000000219271.jpg
# Processing image: data/coco\images/val2017\000000205647.jpg
# Processing image: data/coco\images/val2017\000000460841.jpg
# Processing image: data/coco\images/val2017\000000123131.jpg
# Processing image: data/coco\images/val2017\000000334006.jpg
# Processing image: data/coco\images/val2017\000000511599.jpg
# Processing image: data/coco\images/val2017\000000229858.jpg
# Processing image: data/coco\images/val2017\000000174004.jpg
# Processing image: data/coco\images/val2017\000000519764.jpg
# Processing image: data/coco\images/val2017\000000137576.jpg
# Processing image: data/coco\images/val2017\000000087470.jpg
# Processing image: data/coco\images/val2017\000000009769.jpg
# Processing image: data/coco\images/val2017\000000558114.jpg
# Processing image: data/coco\images/val2017\000000205776.jpg
# Processing image: data/coco\images/val2017\000000163257.jpg
# Processing image: data/coco\images/val2017\000000475678.jpg
# Processing image: data/coco\images/val2017\000000085478.jpg
# Processing image: data/coco\images/val2017\000000318080.jpg
# Processing image: data/coco\images/val2017\000000361551.jpg
# Processing image: data/coco\images/val2017\000000236784.jpg
# Processing image: data/coco\images/val2017\000000092839.jpg
# Processing image: data/coco\images/val2017\000000042296.jpg
# Processing image: data/coco\images/val2017\000000560266.jpg
# Processing image: data/coco\images/val2017\000000486479.jpg
# Processing image: data/coco\images/val2017\000000127955.jpg
# Processing image: data/coco\images/val2017\000000307658.jpg
# Processing image: data/coco\images/val2017\000000417465.jpg
# Processing image: data/coco\images/val2017\000000342971.jpg
# Processing image: data/coco\images/val2017\000000011760.jpg
# Processing image: data/coco\images/val2017\000000069106.jpg
# Processing image: data/coco\images/val2017\000000070158.jpg
# Processing image: data/coco\images/val2017\000000176634.jpg
# Processing image: data/coco\images/val2017\000000281447.jpg
# Processing image: data/coco\images/val2017\000000552371.jpg
# Processing image: data/coco\images/val2017\000000361919.jpg
# Processing image: data/coco\images/val2017\000000560256.jpg
# Processing image: data/coco\images/val2017\000000138115.jpg
# Processing image: data/coco\images/val2017\000000114871.jpg
# Processing image: data/coco\images/val2017\000000374369.jpg
# Processing image: data/coco\images/val2017\000000123213.jpg
# Processing image: data/coco\images/val2017\000000123321.jpg
# Processing image: data/coco\images/val2017\000000015278.jpg
# Processing image: data/coco\images/val2017\000000357742.jpg
# Processing image: data/coco\images/val2017\000000439854.jpg
# Processing image: data/coco\images/val2017\000000465836.jpg
# Processing image: data/coco\images/val2017\000000414385.jpg
# Processing image: data/coco\images/val2017\000000131556.jpg
# Processing image: data/coco\images/val2017\000000322724.jpg
# Processing image: data/coco\images/val2017\000000320664.jpg
# Processing image: data/coco\images/val2017\000000481390.jpg
# Processing image: data/coco\images/val2017\000000109916.jpg
# Processing image: data/coco\images/val2017\000000276434.jpg
# Processing image: data/coco\images/val2017\000000579635.jpg
# Processing image: data/coco\images/val2017\000000295316.jpg
# Processing image: data/coco\images/val2017\000000571313.jpg
# Processing image: data/coco\images/val2017\000000183127.jpg
# Processing image: data/coco\images/val2017\000000115898.jpg
# Processing image: data/coco\images/val2017\000000146358.jpg
# Processing image: data/coco\images/val2017\000000329542.jpg
# Processing image: data/coco\images/val2017\000000189752.jpg
# Processing image: data/coco\images/val2017\000000290163.jpg
# Processing image: data/coco\images/val2017\000000091406.jpg
# Processing image: data/coco\images/val2017\000000322352.jpg
# Processing image: data/coco\images/val2017\000000223959.jpg
# Processing image: data/coco\images/val2017\000000326248.jpg
# Processing image: data/coco\images/val2017\000000218439.jpg
# Processing image: data/coco\images/val2017\000000453722.jpg
# Processing image: data/coco\images/val2017\000000293625.jpg
# Processing image: data/coco\images/val2017\000000411817.jpg
# Processing image: data/coco\images/val2017\000000546964.jpg
# Processing image: data/coco\images/val2017\000000215259.jpg
# Processing image: data/coco\images/val2017\000000573094.jpg
# Processing image: data/coco\images/val2017\000000560011.jpg
# Processing image: data/coco\images/val2017\000000038576.jpg
# Processing image: data/coco\images/val2017\000000147729.jpg
# Processing image: data/coco\images/val2017\000000579307.jpg
# Processing image: data/coco\images/val2017\000000154425.jpg
# Processing image: data/coco\images/val2017\000000432898.jpg
# Processing image: data/coco\images/val2017\000000404923.jpg
# Processing image: data/coco\images/val2017\000000130586.jpg
# Processing image: data/coco\images/val2017\000000163057.jpg
# Processing image: data/coco\images/val2017\000000007511.jpg
# Processing image: data/coco\images/val2017\000000067406.jpg
# Processing image: data/coco\images/val2017\000000290179.jpg
# Processing image: data/coco\images/val2017\000000248752.jpg
# Processing image: data/coco\images/val2017\000000054593.jpg
# Processing image: data/coco\images/val2017\000000116208.jpg
# Processing image: data/coco\images/val2017\000000340697.jpg
# Processing image: data/coco\images/val2017\000000450303.jpg
# Processing image: data/coco\images/val2017\000000494427.jpg
# Processing image: data/coco\images/val2017\000000137294.jpg
# Processing image: data/coco\images/val2017\000000410880.jpg
# Processing image: data/coco\images/val2017\000000311180.jpg
# Processing image: data/coco\images/val2017\000000091654.jpg
# Processing image: data/coco\images/val2017\000000181796.jpg
# Processing image: data/coco\images/val2017\000000002431.jpg
# Processing image: data/coco\images/val2017\000000349184.jpg
# Processing image: data/coco\images/val2017\000000298396.jpg
# Processing image: data/coco\images/val2017\000000472046.jpg
# Processing image: data/coco\images/val2017\000000074058.jpg
# Processing image: data/coco\images/val2017\000000058029.jpg
# Processing image: data/coco\images/val2017\000000134096.jpg
# Processing image: data/coco\images/val2017\000000111951.jpg
# Processing image: data/coco\images/val2017\000000103585.jpg
# Processing image: data/coco\images/val2017\000000210273.jpg
# Processing image: data/coco\images/val2017\000000352584.jpg
# Processing image: data/coco\images/val2017\000000446651.jpg
# Processing image: data/coco\images/val2017\000000194875.jpg
# Processing image: data/coco\images/val2017\000000052017.jpg
# Processing image: data/coco\images/val2017\000000336309.jpg
# Processing image: data/coco\images/val2017\000000227478.jpg
# Processing image: data/coco\images/val2017\000000339870.jpg
# Processing image: data/coco\images/val2017\000000080666.jpg
# Processing image: data/coco\images/val2017\000000033707.jpg
# Processing image: data/coco\images/val2017\000000327601.jpg
# Processing image: data/coco\images/val2017\000000255749.jpg
# Processing image: data/coco\images/val2017\000000008762.jpg
# Processing image: data/coco\images/val2017\000000526392.jpg
# Processing image: data/coco\images/val2017\000000535578.jpg
# Processing image: data/coco\images/val2017\000000580757.jpg
# Processing image: data/coco\images/val2017\000000165039.jpg
# Processing image: data/coco\images/val2017\000000148719.jpg
# Processing image: data/coco\images/val2017\000000108440.jpg
# Processing image: data/coco\images/val2017\000000489842.jpg
# Processing image: data/coco\images/val2017\000000579818.jpg
# Processing image: data/coco\images/val2017\000000423229.jpg
# Processing image: data/coco\images/val2017\000000323828.jpg
# Processing image: data/coco\images/val2017\000000166287.jpg
# Processing image: data/coco\images/val2017\000000101420.jpg
# Processing image: data/coco\images/val2017\000000334555.jpg
# Processing image: data/coco\images/val2017\000000196759.jpg
# Processing image: data/coco\images/val2017\000000411665.jpg
# Processing image: data/coco\images/val2017\000000061418.jpg
# Processing image: data/coco\images/val2017\000000526751.jpg
# Processing image: data/coco\images/val2017\000000024021.jpg
# Processing image: data/coco\images/val2017\000000277020.jpg
# Processing image: data/coco\images/val2017\000000047828.jpg
# Processing image: data/coco\images/val2017\000000183716.jpg
# Processing image: data/coco\images/val2017\000000271997.jpg
# Processing image: data/coco\images/val2017\000000008532.jpg
# Processing image: data/coco\images/val2017\000000094336.jpg
# Processing image: data/coco\images/val2017\000000390555.jpg
# Processing image: data/coco\images/val2017\000000250282.jpg
# Processing image: data/coco\images/val2017\000000068409.jpg
# Processing image: data/coco\images/val2017\000000002299.jpg
# Processing image: data/coco\images/val2017\000000011051.jpg
# Processing image: data/coco\images/val2017\000000066038.jpg
# Processing image: data/coco\images/val2017\000000360960.jpg
# Processing image: data/coco\images/val2017\000000360097.jpg
# Processing image: data/coco\images/val2017\000000421455.jpg
# Processing image: data/coco\images/val2017\000000504589.jpg
# Processing image: data/coco\images/val2017\000000464522.jpg
# Processing image: data/coco\images/val2017\000000454750.jpg
# Processing image: data/coco\images/val2017\000000509735.jpg
# Processing image: data/coco\images/val2017\000000023034.jpg
# Processing image: data/coco\images/val2017\000000141671.jpg
# Processing image: data/coco\images/val2017\000000506656.jpg
# Processing image: data/coco\images/val2017\000000272566.jpg
# Processing image: data/coco\images/val2017\000000045728.jpg
# Processing image: data/coco\images/val2017\000000424551.jpg
# Processing image: data/coco\images/val2017\000000341719.jpg
# Processing image: data/coco\images/val2017\000000072795.jpg
# Processing image: data/coco\images/val2017\000000078959.jpg
# Processing image: data/coco\images/val2017\000000417285.jpg
# Processing image: data/coco\images/val2017\000000002157.jpg
# Processing image: data/coco\images/val2017\000000043816.jpg
# Processing image: data/coco\images/val2017\000000455555.jpg
# Processing image: data/coco\images/val2017\000000535306.jpg
# Processing image: data/coco\images/val2017\000000030504.jpg
# Processing image: data/coco\images/val2017\000000093353.jpg
# Processing image: data/coco\images/val2017\000000530052.jpg
# Processing image: data/coco\images/val2017\000000473118.jpg
# Processing image: data/coco\images/val2017\000000091779.jpg
# Processing image: data/coco\images/val2017\000000283113.jpg
# Processing image: data/coco\images/val2017\000000226130.jpg
# Processing image: data/coco\images/val2017\000000097278.jpg
# Processing image: data/coco\images/val2017\000000567640.jpg
# Processing image: data/coco\images/val2017\000000532493.jpg
# Processing image: data/coco\images/val2017\000000045550.jpg
# Processing image: data/coco\images/val2017\000000156643.jpg
# Processing image: data/coco\images/val2017\000000430056.jpg
# Processing image: data/coco\images/val2017\000000410456.jpg
# Processing image: data/coco\images/val2017\000000441286.jpg
# Processing image: data/coco\images/val2017\000000279541.jpg
# Processing image: data/coco\images/val2017\000000000885.jpg
# Processing image: data/coco\images/val2017\000000378284.jpg
# Processing image: data/coco\images/val2017\000000156076.jpg
# Processing image: data/coco\images/val2017\000000143572.jpg
# Processing image: data/coco\images/val2017\000000229849.jpg
# Processing image: data/coco\images/val2017\000000039551.jpg
# Processing image: data/coco\images/val2017\000000056344.jpg
# Processing image: data/coco\images/val2017\000000193348.jpg
# Processing image: data/coco\images/val2017\000000016958.jpg
# Processing image: data/coco\images/val2017\000000572678.jpg
# Processing image: data/coco\images/val2017\000000106235.jpg
# Processing image: data/coco\images/val2017\000000341681.jpg
# Processing image: data/coco\images/val2017\000000083172.jpg
# Processing image: data/coco\images/val2017\000000343524.jpg
# Processing image: data/coco\images/val2017\000000395801.jpg
# Processing image: data/coco\images/val2017\000000388056.jpg
# Processing image: data/coco\images/val2017\000000259690.jpg
# Processing image: data/coco\images/val2017\000000235836.jpg
# Processing image: data/coco\images/val2017\000000343218.jpg
# Processing image: data/coco\images/val2017\000000205105.jpg
# Processing image: data/coco\images/val2017\000000513283.jpg
# Processing image: data/coco\images/val2017\000000176446.jpg
# Processing image: data/coco\images/val2017\000000371677.jpg
# Processing image: data/coco\images/val2017\000000308531.jpg
# Processing image: data/coco\images/val2017\000000497599.jpg
# Processing image: data/coco\images/val2017\000000455352.jpg
# Processing image: data/coco\images/val2017\000000236914.jpg
# Processing image: data/coco\images/val2017\000000232684.jpg
# Processing image: data/coco\images/val2017\000000415238.jpg
# Processing image: data/coco\images/val2017\000000290843.jpg
# Processing image: data/coco\images/val2017\000000519522.jpg
# Processing image: data/coco\images/val2017\000000144784.jpg
# Processing image: data/coco\images/val2017\000000167486.jpg
# Processing image: data/coco\images/val2017\000000392228.jpg
# Processing image: data/coco\images/val2017\000000488673.jpg
# Processing image: data/coco\images/val2017\000000191013.jpg
# Processing image: data/coco\images/val2017\000000080057.jpg
# Processing image: data/coco\images/val2017\000000570169.jpg
# Processing image: data/coco\images/val2017\000000224807.jpg
# Processing image: data/coco\images/val2017\000000163562.jpg
# Processing image: data/coco\images/val2017\000000136355.jpg
# Processing image: data/coco\images/val2017\000000492362.jpg
# Processing image: data/coco\images/val2017\000000102707.jpg
# Processing image: data/coco\images/val2017\000000232563.jpg
# Processing image: data/coco\images/val2017\000000010977.jpg
# Processing image: data/coco\images/val2017\000000051598.jpg
# Processing image: data/coco\images/val2017\000000032285.jpg
# Processing image: data/coco\images/val2017\000000520910.jpg
# Processing image: data/coco\images/val2017\000000131273.jpg
# Processing image: data/coco\images/val2017\000000206411.jpg
# Processing image: data/coco\images/val2017\000000472375.jpg
# Processing image: data/coco\images/val2017\000000481404.jpg
# Processing image: data/coco\images/val2017\000000471991.jpg
# Processing image: data/coco\images/val2017\000000017436.jpg
# Processing image: data/coco\images/val2017\000000177934.jpg
# Processing image: data/coco\images/val2017\000000165518.jpg
# Processing image: data/coco\images/val2017\000000571718.jpg
# Processing image: data/coco\images/val2017\000000459467.jpg
# Processing image: data/coco\images/val2017\000000135673.jpg
# Processing image: data/coco\images/val2017\000000134886.jpg
# Processing image: data/coco\images/val2017\000000485895.jpg
# Processing image: data/coco\images/val2017\000000287545.jpg
# Processing image: data/coco\images/val2017\000000577182.jpg
# Processing image: data/coco\images/val2017\000000289222.jpg
# Processing image: data/coco\images/val2017\000000372819.jpg
# Processing image: data/coco\images/val2017\000000310072.jpg
# Processing image: data/coco\images/val2017\000000087144.jpg
# Processing image: data/coco\images/val2017\000000430875.jpg
# Processing image: data/coco\images/val2017\000000060347.jpg
# Processing image: data/coco\images/val2017\000000042070.jpg
# Processing image: data/coco\images/val2017\000000420916.jpg
# Processing image: data/coco\images/val2017\000000453584.jpg
# Processing image: data/coco\images/val2017\000000296224.jpg
# Processing image: data/coco\images/val2017\000000122606.jpg
# Processing image: data/coco\images/val2017\000000311909.jpg
# Processing image: data/coco\images/val2017\000000579893.jpg
# Processing image: data/coco\images/val2017\000000284296.jpg
# Processing image: data/coco\images/val2017\000000221017.jpg
# Processing image: data/coco\images/val2017\000000315001.jpg
# Processing image: data/coco\images/val2017\000000439715.jpg
# Processing image: data/coco\images/val2017\000000284991.jpg
# Processing image: data/coco\images/val2017\000000389566.jpg
# Processing image: data/coco\images/val2017\000000078843.jpg
# Processing image: data/coco\images/val2017\000000122927.jpg
# Processing image: data/coco\images/val2017\000000225532.jpg
# Processing image: data/coco\images/val2017\000000013659.jpg
# Processing image: data/coco\images/val2017\000000153568.jpg
# Processing image: data/coco\images/val2017\000000395633.jpg
# Processing image: data/coco\images/val2017\000000419096.jpg
# Processing image: data/coco\images/val2017\000000203488.jpg
# Processing image: data/coco\images/val2017\000000361268.jpg
# ...
# Processing image: data/coco\images/val2017\000000086956.jpg
# Processing image: data/coco\images/val2017\000000356094.jpg
# Processing image: data/coco\images/val2017\000000374982.jpg
# Processing image: data/coco\images/val2017\000000161861.jpg
# Processing image: data/coco\images/val2017\000000276921.jpg
# Processing image: data/coco\images/val2017\000000121497.jpg
# Processing image: data/coco\images/val2017\000000355169.jpg
# Processing image: data/coco\images/val2017\000000073118.jpg
# Processing image: data/coco\images/val2017\000000424349.jpg
# Processing image: data/coco\images/val2017\000000159791.jpg
# Processing image: data/coco\images/val2017\000000189213.jpg
# Processing image: data/coco\images/val2017\000000282298.jpg
# Processing image: data/coco\images/val2017\000000031118.jpg
# Processing image: data/coco\images/val2017\000000318114.jpg
# Processing image: data/coco\images/val2017\000000157756.jpg
# Processing image: data/coco\images/val2017\000000557884.jpg
# Processing image: data/coco\images/val2017\000000314264.jpg
# Processing image: data/coco\images/val2017\000000161008.jpg
# Processing image: data/coco\images/val2017\000000569976.jpg
# Processing image: data/coco\images/val2017\000000331569.jpg
# Processing image: data/coco\images/val2017\000000243626.jpg
# Processing image: data/coco\images/val2017\000000368752.jpg
# Processing image: data/coco\images/val2017\000000333745.jpg
# Processing image: data/coco\images/val2017\000000370208.jpg
# Processing image: data/coco\images/val2017\000000055022.jpg
# Processing image: data/coco\images/val2017\000000557172.jpg
# Processing image: data/coco\images/val2017\000000085576.jpg
# Processing image: data/coco\images/val2017\000000192047.jpg
# Processing image: data/coco\images/val2017\000000466156.jpg
# Processing image: data/coco\images/val2017\000000111086.jpg
# Processing image: data/coco\images/val2017\000000564023.jpg
# Processing image: data/coco\images/val2017\000000069213.jpg
# Processing image: data/coco\images/val2017\000000292456.jpg
# Processing image: data/coco\images/val2017\000000453634.jpg
# Processing image: data/coco\images/val2017\000000155154.jpg
# Processing image: data/coco\images/val2017\000000013177.jpg
# Processing image: data/coco\images/val2017\000000037751.jpg
# Processing image: data/coco\images/val2017\000000531134.jpg
# Processing image: data/coco\images/val2017\000000502347.jpg
# Processing image: data/coco\images/val2017\000000159977.jpg
# Processing image: data/coco\images/val2017\000000088951.jpg
# Processing image: data/coco\images/val2017\000000429109.jpg
# Processing image: data/coco\images/val2017\000000320425.jpg
# Processing image: data/coco\images/val2017\000000471567.jpg
# Processing image: data/coco\images/val2017\000000235057.jpg
# Processing image: data/coco\images/val2017\000000150726.jpg
# Processing image: data/coco\images/val2017\000000334371.jpg
# Processing image: data/coco\images/val2017\000000271457.jpg
# Processing image: data/coco\images/val2017\000000008899.jpg
# Processing image: data/coco\images/val2017\000000212895.jpg
# Processing image: data/coco\images/val2017\000000285894.jpg
# Processing image: data/coco\images/val2017\000000054967.jpg
# Processing image: data/coco\images/val2017\000000128372.jpg
# Processing image: data/coco\images/val2017\000000301981.jpg
# Processing image: data/coco\images/val2017\000000404534.jpg
# Processing image: data/coco\images/val2017\000000079565.jpg
# Processing image: data/coco\images/val2017\000000374551.jpg
# Processing image: data/coco\images/val2017\000000499181.jpg
# Processing image: data/coco\images/val2017\000000093154.jpg
# Processing image: data/coco\images/val2017\000000100489.jpg
# Processing image: data/coco\images/val2017\000000447789.jpg
# Processing image: data/coco\images/val2017\000000014226.jpg
# Processing image: data/coco\images/val2017\000000475223.jpg
# Processing image: data/coco\images/val2017\000000149622.jpg
# Processing image: data/coco\images/val2017\000000180188.jpg
# Processing image: data/coco\images/val2017\000000440617.jpg
# Processing image: data/coco\images/val2017\000000376625.jpg
# Processing image: data/coco\images/val2017\000000015440.jpg
# Processing image: data/coco\images/val2017\000000433134.jpg
# Processing image: data/coco\images/val2017\000000478393.jpg
# Processing image: data/coco\images/val2017\000000387383.jpg
# Processing image: data/coco\images/val2017\000000205289.jpg
# Processing image: data/coco\images/val2017\000000522393.jpg
# Processing image: data/coco\images/val2017\000000080274.jpg
# Processing image: data/coco\images/val2017\000000520832.jpg
# Processing image: data/coco\images/val2017\000000250137.jpg
# Processing image: data/coco\images/val2017\000000082821.jpg
# Processing image: data/coco\images/val2017\000000248284.jpg
# Processing image: data/coco\images/val2017\000000158945.jpg
# Processing image: data/coco\images/val2017\000000210789.jpg
# Processing image: data/coco\images/val2017\000000230993.jpg
# Processing image: data/coco\images/val2017\000000121417.jpg
# Processing image: data/coco\images/val2017\000000341469.jpg
# Processing image: data/coco\images/val2017\000000206831.jpg
# Processing image: data/coco\images/val2017\000000453981.jpg
# Processing image: data/coco\images/val2017\000000519611.jpg
# Processing image: data/coco\images/val2017\000000235064.jpg
# Processing image: data/coco\images/val2017\000000308476.jpg
# Processing image: data/coco\images/val2017\000000305695.jpg
# Processing image: data/coco\images/val2017\000000185409.jpg
# Processing image: data/coco\images/val2017\000000104455.jpg
# Processing image: data/coco\images/val2017\000000401244.jpg
# Processing image: data/coco\images/val2017\000000331075.jpg
# Processing image: data/coco\images/val2017\000000355905.jpg
# Processing image: data/coco\images/val2017\000000328337.jpg
# Processing image: data/coco\images/val2017\000000377497.jpg
# Processing image: data/coco\images/val2017\000000007281.jpg
# Processing image: data/coco\images/val2017\000000050380.jpg
# Processing image: data/coco\images/val2017\000000439180.jpg
# Processing image: data/coco\images/val2017\000000513181.jpg
# Processing image: data/coco\images/val2017\000000371472.jpg
# Processing image: data/coco\images/val2017\000000280891.jpg
# Processing image: data/coco\images/val2017\000000054628.jpg
# Processing image: data/coco\images/val2017\000000157928.jpg
# Processing image: data/coco\images/val2017\000000203095.jpg
# Processing image: data/coco\images/val2017\000000017182.jpg
# Processing image: data/coco\images/val2017\000000150649.jpg
# Processing image: data/coco\images/val2017\000000562059.jpg
# Processing image: data/coco\images/val2017\000000407524.jpg
# Processing image: data/coco\images/val2017\000000306437.jpg
# Processing image: data/coco\images/val2017\000000116206.jpg
# Processing image: data/coco\images/val2017\000000393838.jpg
# Processing image: data/coco\images/val2017\000000229553.jpg
# Processing image: data/coco\images/val2017\000000171382.jpg
# Processing image: data/coco\images/val2017\000000094614.jpg
# Processing image: data/coco\images/val2017\000000172649.jpg
# Processing image: data/coco\images/val2017\000000252507.jpg
# Processing image: data/coco\images/val2017\000000326128.jpg
# Processing image: data/coco\images/val2017\000000214539.jpg
# Processing image: data/coco\images/val2017\000000051314.jpg
# Processing image: data/coco\images/val2017\000000556873.jpg
# Processing image: data/coco\images/val2017\000000417911.jpg
# Processing image: data/coco\images/val2017\000000081988.jpg
# Processing image: data/coco\images/val2017\000000554266.jpg
# Processing image: data/coco\images/val2017\000000008629.jpg
# Processing image: data/coco\images/val2017\000000161925.jpg
# Processing image: data/coco\images/val2017\000000064898.jpg
# Processing image: data/coco\images/val2017\000000547854.jpg
# Processing image: data/coco\images/val2017\000000033005.jpg
# Processing image: data/coco\images/val2017\000000388215.jpg
# Processing image: data/coco\images/val2017\000000111609.jpg
# Processing image: data/coco\images/val2017\000000064718.jpg
# Processing image: data/coco\images/val2017\000000546325.jpg
# Processing image: data/coco\images/val2017\000000082688.jpg
# Processing image: data/coco\images/val2017\000000367569.jpg
# Processing image: data/coco\images/val2017\000000209753.jpg
# Processing image: data/coco\images/val2017\000000531135.jpg
# Processing image: data/coco\images/val2017\000000447187.jpg
# Processing image: data/coco\images/val2017\000000311002.jpg
# Processing image: data/coco\images/val2017\000000458045.jpg
# Processing image: data/coco\images/val2017\000000246436.jpg
# Processing image: data/coco\images/val2017\000000440184.jpg
# Processing image: data/coco\images/val2017\000000085157.jpg
# Processing image: data/coco\images/val2017\000000256916.jpg
# Processing image: data/coco\images/val2017\000000504415.jpg
# Processing image: data/coco\images/val2017\000000246522.jpg
# Processing image: data/coco\images/val2017\000000446703.jpg
# Processing image: data/coco\images/val2017\000000367095.jpg
# Processing image: data/coco\images/val2017\000000529148.jpg
# Processing image: data/coco\images/val2017\000000480212.jpg
# Processing image: data/coco\images/val2017\000000442993.jpg
# Processing image: data/coco\images/val2017\000000071938.jpg
# Processing image: data/coco\images/val2017\000000136466.jpg
# Processing image: data/coco\images/val2017\000000028452.jpg
# Processing image: data/coco\images/val2017\000000581482.jpg
# Processing image: data/coco\images/val2017\000000217425.jpg
# Processing image: data/coco\images/val2017\000000140439.jpg
# Processing image: data/coco\images/val2017\000000151820.jpg
# Processing image: data/coco\images/val2017\000000260105.jpg
# Processing image: data/coco\images/val2017\000000127394.jpg
# Processing image: data/coco\images/val2017\000000238410.jpg
# Processing image: data/coco\images/val2017\000000166918.jpg
# Processing image: data/coco\images/val2017\000000290768.jpg
# Processing image: data/coco\images/val2017\000000357567.jpg
# Processing image: data/coco\images/val2017\000000237118.jpg
# Processing image: data/coco\images/val2017\000000343561.jpg
# Processing image: data/coco\images/val2017\000000195165.jpg
# Processing image: data/coco\images/val2017\000000023272.jpg
# Processing image: data/coco\images/val2017\000000464689.jpg
# Processing image: data/coco\images/val2017\000000360943.jpg
# Processing image: data/coco\images/val2017\000000410221.jpg
# Processing image: data/coco\images/val2017\000000245513.jpg
# Processing image: data/coco\images/val2017\000000445365.jpg
# Processing image: data/coco\images/val2017\000000059386.jpg
# Processing image: data/coco\images/val2017\000000279714.jpg
# Processing image: data/coco\images/val2017\000000507042.jpg
# Processing image: data/coco\images/val2017\000000314541.jpg
# Processing image: data/coco\images/val2017\000000341921.jpg
# Processing image: data/coco\images/val2017\000000186449.jpg
# Processing image: data/coco\images/val2017\000000547336.jpg
# Processing image: data/coco\images/val2017\000000226154.jpg
# Processing image: data/coco\images/val2017\000000394275.jpg
# Processing image: data/coco\images/val2017\000000229753.jpg
# Processing image: data/coco\images/val2017\000000261712.jpg
# Processing image: data/coco\images/val2017\000000019042.jpg
# Processing image: data/coco\images/val2017\000000534394.jpg
# Processing image: data/coco\images/val2017\000000322610.jpg
# Processing image: data/coco\images/val2017\000000263299.jpg
# Processing image: data/coco\images/val2017\000000236690.jpg
# Processing image: data/coco\images/val2017\000000252559.jpg
# Processing image: data/coco\images/val2017\000000050145.jpg
# Processing image: data/coco\images/val2017\000000467848.jpg
# Processing image: data/coco\images/val2017\000000572388.jpg
# Processing image: data/coco\images/val2017\000000272212.jpg
# Processing image: data/coco\images/val2017\000000377000.jpg
# Processing image: data/coco\images/val2017\000000198641.jpg
# Processing image: data/coco\images/val2017\000000181421.jpg
# Processing image: data/coco\images/val2017\000000477227.jpg
# Processing image: data/coco\images/val2017\000000119641.jpg
# Processing image: data/coco\images/val2017\000000040083.jpg
# Processing image: data/coco\images/val2017\000000244496.jpg
# Processing image: data/coco\images/val2017\000000565624.jpg
# Processing image: data/coco\images/val2017\000000549220.jpg
# Processing image: data/coco\images/val2017\000000442836.jpg
# Processing image: data/coco\images/val2017\000000428218.jpg
# Processing image: data/coco\images/val2017\000000574297.jpg
# Processing image: data/coco\images/val2017\000000061747.jpg
# Processing image: data/coco\images/val2017\000000553788.jpg
# Processing image: data/coco\images/val2017\000000153510.jpg
# Processing image: data/coco\images/val2017\000000456143.jpg
# Processing image: data/coco\images/val2017\000000157418.jpg
# Processing image: data/coco\images/val2017\000000345469.jpg
# Processing image: data/coco\images/val2017\000000533855.jpg
# Processing image: data/coco\images/val2017\000000389197.jpg
# Processing image: data/coco\images/val2017\000000422998.jpg
# Processing image: data/coco\images/val2017\000000000632.jpg
# Processing image: data/coco\images/val2017\000000477955.jpg
# Processing image: data/coco\images/val2017\000000128675.jpg
# Processing image: data/coco\images/val2017\000000402720.jpg
# Processing image: data/coco\images/val2017\000000179141.jpg
# Processing image: data/coco\images/val2017\000000353096.jpg
# Processing image: data/coco\images/val2017\000000013729.jpg
# Processing image: data/coco\images/val2017\000000391140.jpg
# Processing image: data/coco\images/val2017\000000157046.jpg
# Processing image: data/coco\images/val2017\000000384527.jpg
# Processing image: data/coco\images/val2017\000000478721.jpg
# Processing image: data/coco\images/val2017\000000033759.jpg
# Processing image: data/coco\images/val2017\000000098287.jpg
# Processing image: data/coco\images/val2017\000000158227.jpg
# Processing image: data/coco\images/val2017\000000407646.jpg
# Processing image: data/coco\images/val2017\000000220310.jpg
# Processing image: data/coco\images/val2017\000000512403.jpg
# Processing image: data/coco\images/val2017\000000168974.jpg
# Processing image: data/coco\images/val2017\000000552775.jpg
# Processing image: data/coco\images/val2017\000000394940.jpg
# Processing image: data/coco\images/val2017\000000015335.jpg
# Total images processed: 2317
# Total images skipped (not found): 0
# Sample result:
# {'image_id': 397133, 'category_id': 1, 'keypoints': [59699, 184091, 2, 57831, 185160, 2, 60500, 184269, 0, 61034, 188543, 2, 65837, 198692, 0, 81049, 178572, 2, 84785, 201541, 2, 103200, 169135, 2, 110672, 209019, 2, 110405, 179462, 2, 119212, 203677, 2, 132823, 178750, 2, 133624, 194953, 2, 173121, 175189, 2, 172854, 195309, 2, 212352, 170025, 2, 210750, 197980, 2], 'bbox': [57831, 169135, 154521, 39884], 'score': 1.7647058823529411}
# Number of keypoints: 51
# First few keypoints: [59699, 184091, 2, 57831, 185160, 2]
# Bounding box: [57831, 169135, 154521, 39884]
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=1.57s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.602
# AP: 0.3506445168797054
# AP.5: 0.3506445168797054
# AP.75: 0.3506445168797054
# AP (M): 0.3465346534653465
# AP (L): 0.588500055733169

# %%
import cv2
import numpy as np
import os
import torch
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from SimpleHigherHRNet import SimpleHigherHRNet

# Adjust this to your actual base path
base_path = "data/coco"
image_folder = os.path.join(base_path, "images/val2017")

# Check if the image folder exists
if not os.path.exists(image_folder):
    raise FileNotFoundError(f"Image folder not found: {image_folder}")

# Initialize HigherHRNet model
model = SimpleHigherHRNet(
    c=32,
    nof_joints=17,
    checkpoint_path="simple-HigherHRNet/weights/pose_higher_hrnet_w32_512.pth",
    resolution=512,
    return_bounding_boxes=False,
    max_nof_people=30,
    max_batch_size=16,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)

def process_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to read image: {image_path}")
        return None
    image_height, image_width, _ = image.shape
    joints = model.predict(image)
    
    if len(joints) == 0:
        return None

    # We'll just use the first person detected for simplicity
    person_joints = joints[0]
    
    coco_keypoints = []
    x_coords = []
    y_coords = []
    for x, y, confidence in person_joints:
        x_pixel = int(x * image_width)
        y_pixel = int(y * image_height)
        coco_keypoints.extend([x_pixel, y_pixel, 2 if confidence > 0.1 else 0])
        if confidence > 0.1:
            x_coords.append(x_pixel)
            y_coords.append(y_pixel)
    
    if x_coords and y_coords:
        x_min, x_max = min(x_coords), max(x_coords)
        y_min, y_max = min(y_coords), max(y_coords)
        width = x_max - x_min
        height = y_max - y_min
        bbox = [x_min, y_min, width, height]
    else:
        bbox = [0, 0, 0, 0]
    
    return coco_keypoints, bbox if len(coco_keypoints) == 51 else None

# Process COCO dataset
coco = COCO(os.path.join(base_path, 'annotations/person_keypoints_val2017.json'))
results = []
processed_count = 0
skipped_count = 0

for img_id in coco.getImgIds()[:50]:  # Limiting to the first 50 images
    img_info = coco.loadImgs(img_id)[0]
    image_path = os.path.join(image_folder, img_info['file_name'])
    if os.path.exists(image_path):
        print(f"Processing image: {image_path}")
        result = process_image(image_path)
        if result:
            keypoints, bbox = result
            result = {
                'image_id': img_id,
                'category_id': 1,  # person category
                'keypoints': keypoints,
                'bbox': bbox,
                'score': np.mean([kp for i, kp in enumerate(keypoints) if i % 3 == 2])  # average confidence
            }
            results.append(result)
            processed_count += 1
    else:
        print(f"Image not found: {image_path}")
        skipped_count += 1

print(f"Total images processed: {processed_count}")
print(f"Total images skipped (not found): {skipped_count}")

# Print a sample result
if results:
    print("Sample result:")
    print(results[0])
    print("Number of keypoints:", len(results[0]['keypoints']))
    print("First few keypoints:", results[0]['keypoints'][:6])
    print("Bounding box:", results[0]['bbox'])

# Evaluate
if results:
    coco_dt = coco.loadRes(results)
    coco_eval = COCOeval(coco, coco_dt, 'keypoints')
    coco_eval.params.imgIds = [r['image_id'] for r in results]  # Only evaluate on processed images
    coco_eval.evaluate()
    coco_eval.accumulate()
    coco_eval.summarize()
    print(f"AP: {coco_eval.stats[0]}")
    print(f"AP.5: {coco_eval.stats[1]}")
    print(f"AP.75: {coco_eval.stats[2]}")
    print(f"AP (M): {coco_eval.stats[3]}")
    print(f"AP (L): {coco_eval.stats[4]}")
else:
    print("No results to evaluate. Check if any images were successfully processed.")
