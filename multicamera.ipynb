# %% [markdown]
# Basic Imports

# %%
import os
import sys
import argparse
import cv2
import time
import torch
from vidgear.gears import CamGear
import numpy as np

# HRNet Directory
sys.path.append('models/simple-HigherHRNet')

# Import the required HRNet model classes and utilities
from SimpleHigherHRNet import SimpleHigherHRNet
from misc.visualization import draw_points, draw_skeleton, draw_points_and_skeleton, joints_dict, check_video_rotation
from misc.utils import find_person_id_associations

# %% [markdown]
# Testing Camera

# %%
import cv2

cam0 = cv2.VideoCapture(0)
cam1 = cv2.VideoCapture(1)
cam2 = cv2.VideoCapture(2)

while True:
    ret1, frame1 = cam0.read()
    ret2, frame2 = cam2.read()

    frame1 = cv2.flip(frame1, 1)
    frame2 = cv2.flip(frame2, 1)

    if(ret1):
        cv2.imshow('cam1', frame1)    
    if(ret2):
        cv2.imshow('cam2', frame2)  
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break      
cam1.release()
cam2.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Capture Images
#
# Press 'q' to quit, 'c' to capture images, 't' to capture a specified number of images

# %%
import cv2
from pathlib import Path
from datetime import datetime, timedelta

pathname = input("Please input the desired path name")

# Initialize video capture for two cameras
cam1 = cv2.VideoCapture(1)
cam2 = cv2.VideoCapture(2)

# Create directories for saving images
data_dir = Path(pathname)
cam1_dir = data_dir / 'cam1'
cam2_dir = data_dir / 'cam2'
cam1_dir.mkdir(parents=True, exist_ok=True)
cam2_dir.mkdir(parents=True, exist_ok=True)

# Capture settings
print("Press 'q' to quit, 'c' to capture images, 't' to capture a specified number of images")
num_images_to_capture = int(input("How many pictures do you want to take? "))

# img_count = 0  # Image counter to synchronize images from both cameras
# capture_delay = timedelta(seconds=0.1)  # Time between captures

def capture_and_save_images(img_count):
    """Captures and saves images from both cameras with a timestamp."""
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    cam1_filename = cam1_dir / f'cam1_{timestamp}_{img_count:04d}.png'
    cam2_filename = cam2_dir / f'cam2_{timestamp}_{img_count:04d}.png'

    ret1, frame1 = cam1.read()
    ret2, frame2 = cam2.read()

    frame1 = cv2.flip(frame1, 1)
    frame2 = cv2.flip(frame2, 1)

    if ret1 and ret2:
        cv2.imwrite(str(cam1_filename), frame1)
        cv2.imwrite(str(cam2_filename), frame2)
        print(f"Captured: {cam1_filename} and {cam2_filename}")
    else:
        print("Failed to capture image from one or both cameras.")

frame_counter = 100 # for the file name
is_capturing = False

images_captured = 0 # counting the pictures

last_capture_time = 0 # couuting the time interval, so each 0.1 second one picture will be taken

while True:
    ret1, frame1 = cam1.read()
    ret2, frame2 = cam2.read()

    frame1 = cv2.flip(frame1, 1)
    frame2 = cv2.flip(frame2, 1)

    if ret1:
        cv2.imshow('Camera 1', frame1)
    if ret2:
        cv2.imshow('Camera 2', frame2)
    # Capture image if in capture mode
    current_time = time.time() # get the current time in whlie loop
    if is_capturing and (current_time - last_capture_time) >= 0.001: # capture interval default set as 0.1 second

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        cam1_filename = cam1_dir / f'cam1_{timestamp}_{images_captured:04d}.png'
        cam2_filename = cam2_dir / f'cam2_{timestamp}_{images_captured:04d}.png'

        cv2.imwrite(str(cam1_filename), frame1)
        cv2.imwrite(str(cam2_filename), frame2)
        

        frame_counter += 1
        images_captured += 1
        last_capture_time = current_time
        print(f"Captured: {cam1_filename} and {cam2_filename}")

        if images_captured >= num_images_to_capture: # stoping conditions if the taken pipcutures exceed the expected numbers
            is_capturing = False
            print("Finished capturing images.")

    key = cv2.waitKey(10) & 0xFF

    if key == ord('q'):  # Quit the program
        break
    elif key == ord('c'):  # Capture one set of images
        capture_and_save_images(images_captured)
        images_captured += 1
    elif key == ord('t'):  # Press 't' to start capturing images
        
        # capture_interval = float(input("Enter the interval between captures (in seconds): "))
        # print(f"Capturing {num_images_to_capture} images at {capture_interval} second intervals. Get ready to pose!")
        is_capturing = True
        images_captured = 0
        last_capture_time = time.time()
        # time.sleep(5)

# Release the camera resources and close windows
cam1.release()
cam2.release()
cv2.destroyAllWindows()

# %% [markdown]
# img -> pose estimation

# %%
import cv2
import torch
from SimpleHigherHRNet import SimpleHigherHRNet
from misc.visualization import draw_points_and_skeleton, joints_dict
import matplotlib.pyplot as plt
from os import listdir
from pathlib import Path

pathname = input("Please input the path name (for pose estimation)")
pathname = Path(pathname)

#initializing the model
model = SimpleHigherHRNet(
    c=48,
    nof_joints=17,
    checkpoint_path="models/simple-HigherHRNet/weights/pose_higher_hrnet_w48_640.pth.tar",
    resolution=640,
    return_bounding_boxes=False,
    max_nof_people=30,
    max_batch_size=16,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)
print("Model initialized successfully.")

#images path
folder_cam1 = pathname / "cam1"
folder_cam2 = pathname / "cam2"

#new path for pose estimation
# data_dir = Path('data_bruh_jack')
cam1_new_dir = pathname / 'cam1_pose'
cam2_new_dir = pathname / 'cam2_pose'

cam1_new_dir.mkdir(parents=True, exist_ok=True)
cam2_new_dir.mkdir(parents=True, exist_ok=True)

def pose_estimate(image_dir, output_dir):
    #Create a new txt file storing the joints
    f = open(f"{image_dir}.txt", "w")

    for image_cam in listdir(image_dir):
        image_path = os.path.join(image_dir, image_cam)
        image = cv2.imread(image_path)

        # Check if the image was loaded correctly
        if image is None:
            raise ValueError(f"Image at path '{image_path}' could not be loaded. Please check the path.")
        print("Image loaded successfully.")

        #predict the joints
        joints = model.predict(image)
        
        # Check if joints were detected
        if len(joints) == 0:
            print("No joints detected.")
        else:
            print(f"Detected joints for {len(joints)} people.")

        # Draw the keypoints and skeleton on the image
        if len(joints) > 0:
            skeleton = joints_dict()['coco']['skeleton']
            image = draw_points_and_skeleton(image, joints[0], skeleton, points_color_palette='gist_rainbow', skeleton_color_palette='jet')

        #image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) <- for cv2.imshow

        cam_filename = output_dir / image_cam

        cv2.imwrite(str(cam_filename), image)

        #Store the keypoints
        joints_for_superglue = [[int(point[1]), int(point[0])] for point in joints[0] if point[2] >= 0.1]
        

        print(f"image name: {image_path}, joints_for_superglue: {joints_for_superglue}")
        input = str(cam_filename) + " " + str(joints_for_superglue) + "\n"
        # print(input)
        f.write(input)
    
    
    f.close()

#iterate through the image path
pose_estimate(folder_cam1, cam1_new_dir)
pose_estimate(folder_cam2, cam2_new_dir)
# Out:
# device: 'cuda' - 1 GPU(s) will be used
# Model initialized successfully.
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120234_0001.png, joints_for_superglue: [[296, 81], [299, 75], [290, 72], [266, 71], [289, 133], [245, 120], [298, 196], [238, 184], [314, 240], [222, 248], [301, 244], [268, 247], [298, 342], [266, 345], [292, 429], [266, 446]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120234_0002.png, joints_for_superglue: [[296, 81], [299, 75], [290, 72], [266, 71], [290, 133], [246, 119], [298, 195], [237, 183], [315, 240], [220, 248], [301, 245], [267, 249], [298, 344], [266, 346], [292, 429], [267, 447]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120235_0003.png, joints_for_superglue: [[295, 80], [298, 75], [289, 71], [266, 71], [289, 132], [245, 119], [298, 195], [236, 184], [316, 240], [218, 248], [302, 246], [266, 252], [299, 344], [266, 346], [292, 429], [267, 447]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120235_0004.png, joints_for_superglue: [[293, 80], [296, 74], [288, 71], [263, 70], [288, 132], [244, 119], [297, 193], [234, 185], [317, 240], [217, 249], [302, 247], [266, 253], [298, 345], [265, 348], [292, 429], [267, 447]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120235_0005.png, joints_for_superglue: [[292, 78], [295, 72], [286, 68], [261, 68], [289, 131], [241, 117], [299, 190], [232, 183], [319, 238], [215, 247], [302, 245], [263, 249], [302, 341], [264, 348], [298, 427], [267, 447]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120235_0006.png, joints_for_superglue: [[296, 78], [301, 72], [290, 69], [266, 69], [298, 132], [248, 119], [309, 192], [235, 184], [331, 239], [215, 246], [306, 243], [266, 245], [310, 340], [267, 343], [307, 431], [268, 447]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120235_0007.png, joints_for_superglue: [[301, 76], [304, 69], [292, 68], [270, 70], [307, 130], [252, 120], [319, 189], [238, 182], [342, 237], [213, 245], [310, 241], [269, 242], [309, 341], [270, 345], [306, 430], [268, 443]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120236_0008.png, joints_for_superglue: [[298, 76], [301, 69], [289, 67], [268, 70], [305, 131], [250, 121], [320, 191], [234, 183], [343, 237], [207, 246], [309, 241], [268, 243], [309, 342], [269, 349], [307, 429], [268, 446]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120236_0009.png, joints_for_superglue: [[287, 71], [292, 63], [278, 62], [259, 67], [302, 127], [240, 119], [320, 187], [223, 184], [347, 236], [198, 247], [308, 241], [262, 244], [311, 339], [267, 346], [316, 426], [269, 449]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120236_0010.png, joints_for_superglue: [[292, 73], [297, 66], [283, 66], [265, 71], [312, 129], [249, 122], [332, 189], [231, 184], [359, 239], [204, 246], [314, 242], [267, 244], [316, 338], [269, 345], [319, 430], [268, 448]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120236_0011.png, joints_for_superglue: [[290, 72], [297, 64], [281, 64], [266, 71], [316, 128], [250, 123], [337, 188], [231, 185], [363, 239], [203, 246], [314, 240], [267, 241], [316, 337], [271, 340], [319, 429], [272, 444]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120237_0012.png, joints_for_superglue: [[283, 69], [289, 62], [272, 62], [295, 67], [258, 70], [312, 126], [242, 123], [336, 187], [223, 186], [365, 238], [196, 246], [308, 239], [261, 240], [313, 336], [268, 341], [320, 427], [272, 445]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120237_0013.png, joints_for_superglue: [[285, 69], [292, 62], [275, 62], [299, 67], [261, 69], [316, 125], [245, 122], [342, 186], [227, 183], [374, 236], [199, 246], [312, 239], [263, 240], [321, 337], [268, 340], [329, 431], [271, 445]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120237_0014.png, joints_for_superglue: [[289, 70], [296, 62], [279, 63], [305, 68], [266, 70], [323, 126], [252, 123], [348, 186], [233, 182], [378, 237], [203, 245], [319, 239], [270, 241], [324, 339], [272, 342], [329, 431], [272, 445]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120237_0015.png, joints_for_superglue: [[289, 69], [296, 61], [279, 62], [306, 66], [268, 70], [327, 123], [254, 123], [351, 184], [234, 182], [382, 237], [203, 244], [321, 239], [271, 240], [324, 340], [275, 342], [329, 432], [277, 442]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120237_0016.png, joints_for_superglue: [[277, 70], [285, 62], [268, 63], [296, 66], [257, 71], [319, 123], [245, 125], [346, 183], [224, 189], [378, 236], [196, 248], [314, 237], [264, 239], [319, 338], [270, 342], [329, 432], [276, 444]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120238_0017.png, joints_for_superglue: [[275, 68], [283, 60], [266, 61], [295, 65], [257, 69], [319, 122], [244, 124], [347, 181], [225, 189], [381, 235], [197, 246], [311, 234], [262, 237], [323, 338], [268, 343], [338, 434], [276, 444]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120238_0018.png, joints_for_superglue: [[285, 69], [293, 61], [275, 63], [306, 65], [268, 69], [331, 122], [256, 125], [356, 182], [235, 188], [389, 239], [205, 244], [321, 239], [271, 240], [328, 345], [272, 345], [339, 437], [277, 443]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120238_0019.png, joints_for_superglue: [[284, 69], [292, 60], [275, 63], [308, 63], [269, 68], [334, 120], [259, 125], [360, 180], [239, 187], [392, 238], [208, 244], [323, 244], [273, 244], [328, 345], [276, 346], [339, 436], [288, 441]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20240912_120238_0020.png, joints_for_superglue: [[274, 69], [281, 61], [265, 63], [298, 64], [326, 121], [250, 126], [352, 180], [233, 189], [385, 237], [206, 246], [315, 242], [267, 242], [324, 345], [275, 350], [339, 435], [287, 441]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205353_0000.png, joints_for_superglue: [[355, 53], [364, 44], [350, 47], [383, 49], [403, 102], [344, 113], [419, 171], [338, 178], [424, 236], [320, 231], [388, 239], [346, 237], [403, 341], [359, 331], [417, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205353_0001.png, joints_for_superglue: [[355, 53], [365, 44], [350, 47], [383, 49], [403, 102], [344, 113], [419, 171], [338, 177], [424, 236], [319, 231], [388, 239], [347, 236], [403, 340], [359, 331], [417, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205353_0002.png, joints_for_superglue: [[355, 53], [365, 44], [350, 47], [383, 49], [402, 102], [343, 113], [419, 170], [337, 178], [424, 236], [319, 231], [388, 238], [346, 234], [402, 339], [359, 331], [417, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0003.png, joints_for_superglue: [[356, 53], [365, 44], [350, 47], [383, 49], [402, 102], [343, 113], [419, 171], [337, 178], [423, 236], [319, 232], [388, 238], [346, 235], [402, 340], [359, 331], [417, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0004.png, joints_for_superglue: [[356, 53], [365, 44], [350, 47], [383, 49], [402, 102], [343, 113], [419, 171], [337, 178], [423, 236], [319, 232], [388, 238], [346, 235], [402, 339], [358, 331], [417, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0005.png, joints_for_superglue: [[356, 53], [365, 45], [350, 47], [383, 49], [401, 102], [343, 113], [418, 170], [336, 178], [421, 235], [318, 232], [387, 238], [346, 234], [401, 339], [358, 330], [417, 426], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0006.png, joints_for_superglue: [[356, 53], [365, 45], [350, 47], [383, 49], [401, 102], [343, 113], [418, 170], [336, 178], [421, 235], [318, 231], [387, 238], [346, 235], [401, 339], [358, 330], [416, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0007.png, joints_for_superglue: [[356, 53], [365, 45], [350, 47], [383, 49], [402, 102], [343, 113], [418, 170], [336, 177], [421, 235], [318, 231], [387, 239], [346, 236], [401, 339], [358, 330], [416, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0008.png, joints_for_superglue: [[356, 53], [365, 44], [350, 47], [383, 49], [401, 102], [343, 113], [418, 170], [336, 177], [421, 235], [318, 231], [387, 237], [346, 234], [401, 339], [358, 330], [417, 426], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0009.png, joints_for_superglue: [[356, 53], [365, 44], [350, 47], [383, 49], [401, 102], [343, 113], [418, 170], [336, 177], [421, 235], [318, 231], [387, 237], [346, 234], [401, 339], [358, 330], [417, 426], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0010.png, joints_for_superglue: [[356, 53], [365, 44], [350, 47], [383, 49], [401, 102], [343, 113], [418, 170], [336, 177], [421, 234], [318, 231], [387, 238], [346, 235], [401, 339], [358, 330], [417, 426], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0011.png, joints_for_superglue: [[357, 52], [367, 44], [350, 46], [384, 48], [402, 101], [343, 113], [419, 170], [336, 177], [422, 235], [318, 231], [388, 238], [347, 236], [401, 339], [358, 330], [417, 426], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0012.png, joints_for_superglue: [[359, 52], [368, 43], [352, 45], [385, 48], [404, 101], [344, 112], [421, 170], [337, 177], [424, 235], [319, 231], [389, 239], [347, 237], [402, 339], [358, 331], [417, 426], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0013.png, joints_for_superglue: [[359, 51], [369, 43], [353, 45], [386, 48], [404, 101], [345, 112], [421, 170], [338, 176], [425, 236], [319, 231], [390, 239], [347, 236], [403, 339], [358, 331], [417, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0014.png, joints_for_superglue: [[360, 51], [370, 43], [353, 45], [387, 48], [405, 101], [345, 112], [422, 170], [338, 176], [426, 235], [320, 231], [391, 238], [348, 235], [403, 340], [358, 331], [417, 425], [367, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0015.png, joints_for_superglue: [[362, 50], [372, 41], [356, 44], [389, 47], [407, 100], [346, 111], [425, 168], [340, 177], [430, 236], [322, 231], [392, 239], [348, 237], [405, 342], [356, 331], [417, 425], [366, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0016.png, joints_for_superglue: [[363, 50], [372, 41], [356, 43], [390, 47], [408, 99], [346, 111], [425, 168], [340, 177], [431, 235], [322, 231], [392, 239], [347, 237], [405, 342], [354, 331], [417, 425], [366, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0017.png, joints_for_superglue: [[363, 49], [372, 41], [356, 42], [389, 47], [409, 99], [346, 111], [425, 168], [339, 176], [431, 234], [321, 230], [392, 241], [347, 239], [406, 343], [353, 331], [417, 426], [365, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0018.png, joints_for_superglue: [[362, 49], [371, 40], [355, 42], [389, 46], [408, 99], [345, 111], [425, 168], [338, 177], [432, 233], [319, 231], [391, 241], [347, 239], [405, 341], [353, 329], [417, 426], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0019.png, joints_for_superglue: [[361, 50], [371, 41], [355, 43], [388, 47], [349, 48], [406, 99], [344, 111], [425, 168], [336, 177], [432, 233], [317, 231], [391, 241], [346, 236], [404, 339], [352, 329], [417, 426], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0020.png, joints_for_superglue: [[361, 50], [371, 41], [355, 43], [388, 47], [349, 48], [406, 99], [344, 111], [425, 168], [336, 177], [432, 233], [317, 231], [391, 241], [346, 236], [404, 339], [352, 329], [417, 426], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0021.png, joints_for_superglue: [[360, 50], [370, 41], [354, 43], [386, 47], [405, 101], [343, 111], [424, 169], [334, 178], [431, 233], [315, 231], [389, 241], [345, 236], [403, 340], [352, 330], [417, 426], [362, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205354_0022.png, joints_for_superglue: [[359, 51], [368, 42], [352, 44], [385, 48], [403, 101], [341, 112], [422, 170], [332, 177], [431, 232], [313, 231], [388, 239], [344, 234], [402, 340], [351, 331], [416, 426], [363, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0023.png, joints_for_superglue: [[352, 53], [362, 44], [346, 46], [378, 50], [396, 103], [334, 113], [415, 167], [326, 177], [428, 230], [306, 230], [383, 237], [340, 235], [397, 339], [350, 330], [416, 425], [363, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0024.png, joints_for_superglue: [[351, 53], [360, 45], [345, 46], [377, 50], [339, 51], [394, 104], [332, 113], [414, 167], [324, 177], [428, 230], [304, 230], [382, 235], [339, 233], [395, 335], [350, 329], [415, 423], [363, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0025.png, joints_for_superglue: [[350, 53], [359, 45], [344, 46], [376, 50], [393, 104], [331, 112], [413, 166], [323, 176], [428, 230], [302, 230], [381, 234], [338, 233], [394, 333], [350, 328], [414, 422], [363, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0026.png, joints_for_superglue: [[350, 53], [359, 45], [343, 46], [375, 50], [338, 51], [393, 103], [331, 112], [412, 165], [322, 176], [428, 228], [302, 230], [381, 233], [338, 231], [392, 331], [349, 328], [413, 421], [363, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0027.png, joints_for_superglue: [[350, 52], [359, 44], [343, 45], [375, 50], [338, 51], [393, 103], [330, 111], [412, 164], [322, 175], [429, 228], [302, 229], [381, 232], [338, 230], [392, 330], [349, 327], [412, 419], [362, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0028.png, joints_for_superglue: [[350, 51], [360, 43], [344, 45], [375, 50], [338, 50], [393, 103], [330, 111], [413, 163], [321, 174], [430, 228], [302, 229], [381, 230], [338, 229], [392, 330], [348, 327], [411, 419], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0029.png, joints_for_superglue: [[352, 51], [361, 43], [345, 45], [376, 49], [339, 51], [394, 103], [331, 111], [414, 163], [322, 174], [431, 227], [302, 228], [382, 230], [338, 229], [392, 327], [349, 327], [410, 419], [362, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0030.png, joints_for_superglue: [[358, 51], [367, 43], [351, 45], [382, 48], [344, 51], [401, 103], [335, 112], [422, 167], [325, 176], [440, 228], [305, 229], [389, 233], [343, 231], [394, 328], [351, 327], [409, 419], [362, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0031.png, joints_for_superglue: [[360, 51], [369, 42], [353, 44], [384, 48], [346, 50], [404, 103], [338, 111], [425, 166], [326, 176], [442, 228], [307, 229], [391, 233], [345, 230], [396, 327], [351, 326], [409, 418], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0032.png, joints_for_superglue: [[362, 50], [371, 42], [355, 44], [386, 47], [349, 49], [407, 103], [339, 111], [427, 167], [328, 176], [444, 228], [308, 228], [393, 235], [346, 232], [398, 330], [352, 326], [410, 418], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0033.png, joints_for_superglue: [[364, 49], [373, 41], [357, 43], [389, 47], [351, 49], [409, 102], [340, 110], [428, 165], [330, 175], [446, 228], [308, 227], [395, 233], [347, 231], [399, 330], [353, 327], [410, 419], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0034.png, joints_for_superglue: [[367, 48], [376, 41], [359, 42], [391, 46], [353, 48], [411, 102], [342, 109], [430, 165], [332, 173], [448, 228], [309, 227], [397, 234], [348, 232], [401, 335], [353, 327], [411, 419], [362, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0035.png, joints_for_superglue: [[368, 48], [378, 40], [361, 41], [393, 46], [354, 48], [412, 102], [343, 109], [432, 165], [333, 172], [450, 229], [310, 227], [398, 234], [350, 232], [402, 332], [353, 325], [412, 419], [361, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0036.png, joints_for_superglue: [[370, 47], [379, 39], [363, 40], [394, 46], [356, 47], [414, 101], [343, 109], [433, 166], [334, 171], [451, 228], [311, 226], [399, 233], [350, 231], [403, 330], [353, 324], [412, 419], [361, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0037.png, joints_for_superglue: [[373, 45], [383, 37], [366, 38], [397, 44], [359, 45], [418, 99], [344, 107], [435, 163], [334, 169], [454, 226], [310, 225], [402, 229], [352, 226], [406, 326], [351, 321], [412, 418], [352, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0038.png, joints_for_superglue: [[373, 45], [383, 37], [366, 38], [397, 44], [358, 46], [417, 99], [344, 107], [434, 164], [334, 169], [454, 226], [309, 225], [402, 228], [352, 225], [407, 326], [350, 321], [412, 418], [349, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0039.png, joints_for_superglue: [[373, 45], [382, 37], [365, 39], [397, 45], [358, 47], [416, 100], [343, 107], [434, 164], [332, 168], [454, 226], [308, 225], [403, 228], [352, 226], [407, 326], [349, 322], [412, 419], [347, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0040.png, joints_for_superglue: [[372, 46], [381, 38], [365, 39], [395, 45], [357, 48], [415, 100], [343, 107], [433, 164], [331, 168], [453, 226], [307, 226], [402, 229], [351, 227], [407, 327], [348, 323], [412, 419], [346, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0041.png, joints_for_superglue: [[365, 50], [374, 42], [358, 43], [388, 48], [350, 50], [409, 104], [336, 111], [427, 168], [324, 171], [450, 228], [299, 229], [397, 230], [346, 231], [406, 327], [346, 326], [412, 419], [345, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205355_0042.png, joints_for_superglue: [[363, 50], [372, 42], [356, 44], [386, 48], [348, 51], [406, 105], [334, 111], [425, 168], [322, 171], [450, 230], [296, 229], [395, 232], [344, 231], [404, 329], [345, 326], [412, 418], [345, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0043.png, joints_for_superglue: [[360, 51], [370, 43], [353, 45], [383, 49], [345, 51], [403, 105], [332, 111], [422, 168], [319, 172], [448, 230], [294, 230], [393, 234], [343, 232], [403, 329], [344, 327], [412, 418], [345, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0044.png, joints_for_superglue: [[358, 51], [367, 44], [350, 45], [381, 50], [343, 51], [400, 105], [330, 111], [421, 169], [317, 171], [446, 229], [291, 230], [391, 236], [340, 233], [400, 327], [344, 326], [411, 419], [345, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0045.png, joints_for_superglue: [[355, 52], [364, 45], [348, 46], [378, 50], [340, 53], [398, 105], [328, 112], [419, 169], [315, 173], [445, 228], [289, 230], [388, 234], [337, 233], [398, 326], [343, 326], [410, 417], [345, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0046.png, joints_for_superglue: [[352, 53], [361, 45], [346, 47], [375, 50], [338, 53], [395, 106], [325, 113], [416, 169], [313, 173], [443, 228], [287, 230], [386, 234], [335, 233], [395, 326], [341, 326], [410, 417], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0047.png, joints_for_superglue: [[349, 54], [358, 46], [343, 47], [372, 51], [336, 54], [392, 107], [322, 114], [414, 170], [310, 174], [442, 228], [284, 231], [383, 234], [334, 232], [393, 326], [340, 326], [409, 418], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0048.png, joints_for_superglue: [[339, 56], [348, 48], [332, 50], [362, 53], [325, 56], [383, 108], [313, 116], [406, 169], [301, 176], [436, 227], [277, 232], [373, 237], [326, 236], [385, 328], [336, 325], [408, 418], [344, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0049.png, joints_for_superglue: [[337, 57], [345, 49], [329, 51], [359, 54], [323, 56], [380, 108], [311, 117], [404, 170], [299, 177], [433, 225], [275, 233], [372, 237], [325, 237], [384, 329], [335, 326], [408, 418], [344, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0050.png, joints_for_superglue: [[334, 57], [343, 50], [327, 51], [357, 55], [321, 58], [378, 108], [309, 117], [403, 170], [296, 179], [431, 225], [273, 233], [370, 237], [323, 237], [383, 330], [335, 326], [408, 418], [344, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0051.png, joints_for_superglue: [[332, 58], [341, 50], [325, 52], [355, 55], [318, 59], [376, 109], [308, 117], [400, 168], [295, 179], [431, 225], [271, 234], [370, 238], [322, 238], [383, 332], [335, 328], [408, 419], [344, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0052.png, joints_for_superglue: [[330, 59], [338, 51], [323, 53], [353, 55], [317, 60], [374, 109], [306, 118], [399, 169], [294, 179], [429, 225], [270, 234], [369, 238], [322, 237], [383, 332], [333, 326], [407, 418], [344, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0053.png, joints_for_superglue: [[328, 59], [337, 51], [322, 53], [351, 56], [315, 60], [373, 110], [304, 118], [398, 170], [292, 179], [428, 225], [269, 234], [368, 237], [320, 236], [383, 333], [334, 326], [408, 418], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0054.png, joints_for_superglue: [[323, 60], [331, 52], [316, 54], [346, 57], [310, 61], [368, 110], [299, 119], [394, 169], [288, 180], [425, 223], [265, 235], [365, 236], [317, 235], [380, 327], [332, 326], [409, 416], [343, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0055.png, joints_for_superglue: [[322, 60], [331, 52], [315, 54], [345, 57], [309, 60], [367, 110], [299, 120], [393, 169], [287, 180], [424, 223], [265, 235], [364, 236], [317, 235], [380, 325], [332, 325], [409, 416], [343, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0056.png, joints_for_superglue: [[322, 60], [330, 52], [314, 54], [345, 57], [309, 60], [367, 110], [298, 119], [392, 169], [287, 180], [424, 222], [265, 235], [364, 234], [317, 233], [380, 324], [332, 325], [410, 416], [343, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0057.png, joints_for_superglue: [[321, 60], [330, 52], [314, 54], [344, 57], [308, 60], [367, 110], [298, 119], [392, 168], [286, 180], [424, 222], [264, 235], [364, 233], [316, 232], [380, 324], [332, 325], [410, 416], [343, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0058.png, joints_for_superglue: [[321, 60], [330, 52], [314, 54], [344, 57], [308, 60], [366, 110], [297, 119], [392, 169], [286, 180], [424, 222], [264, 235], [364, 233], [316, 233], [380, 324], [332, 325], [411, 416], [343, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0059.png, joints_for_superglue: [[323, 60], [331, 53], [316, 54], [345, 57], [309, 61], [367, 110], [297, 119], [392, 168], [285, 180], [425, 221], [264, 235], [365, 234], [317, 234], [381, 322], [332, 324], [411, 413], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0060.png, joints_for_superglue: [[323, 60], [332, 52], [316, 54], [346, 57], [310, 61], [367, 110], [297, 119], [392, 169], [285, 180], [425, 222], [264, 235], [366, 236], [317, 236], [382, 322], [332, 325], [410, 413], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0061.png, joints_for_superglue: [[324, 60], [332, 52], [317, 54], [346, 57], [310, 60], [368, 110], [298, 119], [392, 168], [286, 180], [426, 222], [264, 235], [367, 236], [317, 236], [382, 324], [333, 326], [410, 413], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205356_0062.png, joints_for_superglue: [[325, 60], [334, 52], [317, 54], [347, 57], [311, 60], [368, 110], [299, 119], [394, 168], [286, 179], [427, 222], [265, 235], [367, 236], [318, 236], [383, 325], [334, 326], [408, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0063.png, joints_for_superglue: [[325, 60], [334, 52], [319, 54], [348, 57], [312, 60], [369, 110], [299, 119], [394, 168], [287, 179], [428, 222], [265, 235], [368, 235], [319, 235], [382, 324], [334, 324], [407, 411], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0064.png, joints_for_superglue: [[327, 59], [335, 52], [320, 53], [349, 57], [313, 60], [370, 110], [300, 118], [395, 169], [288, 179], [430, 222], [266, 234], [369, 236], [320, 236], [382, 325], [334, 325], [404, 411], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0065.png, joints_for_superglue: [[333, 59], [341, 52], [326, 53], [355, 57], [318, 60], [375, 110], [305, 118], [401, 169], [292, 179], [435, 223], [269, 235], [373, 233], [324, 237], [382, 325], [335, 324], [401, 411], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0066.png, joints_for_superglue: [[334, 59], [343, 52], [328, 53], [356, 57], [320, 60], [377, 110], [307, 118], [403, 170], [293, 179], [436, 223], [271, 235], [373, 230], [325, 233], [383, 324], [336, 324], [401, 411], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0067.png, joints_for_superglue: [[337, 59], [345, 51], [329, 53], [358, 57], [321, 60], [379, 110], [308, 118], [404, 170], [294, 179], [437, 224], [273, 234], [375, 229], [326, 232], [384, 323], [337, 324], [402, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0068.png, joints_for_superglue: [[338, 59], [347, 51], [331, 53], [360, 56], [323, 60], [381, 110], [310, 118], [406, 170], [295, 179], [439, 224], [274, 234], [377, 229], [328, 232], [386, 324], [338, 325], [402, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0069.png, joints_for_superglue: [[340, 58], [349, 51], [333, 52], [361, 56], [325, 60], [382, 110], [311, 117], [407, 170], [297, 178], [440, 224], [276, 234], [379, 230], [329, 233], [387, 324], [338, 324], [402, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0070.png, joints_for_superglue: [[342, 58], [350, 51], [335, 52], [363, 56], [327, 59], [383, 110], [312, 117], [408, 170], [299, 178], [442, 224], [277, 234], [379, 228], [331, 232], [388, 324], [338, 322], [402, 411], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0071.png, joints_for_superglue: [[349, 57], [358, 50], [342, 51], [370, 56], [333, 58], [389, 109], [318, 116], [413, 170], [303, 177], [446, 225], [282, 233], [384, 228], [334, 231], [391, 324], [341, 324], [402, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0072.png, joints_for_superglue: [[350, 57], [359, 50], [344, 50], [371, 56], [335, 57], [391, 109], [319, 116], [414, 169], [305, 176], [447, 225], [282, 234], [385, 230], [336, 233], [392, 324], [342, 324], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0073.png, joints_for_superglue: [[352, 56], [361, 49], [345, 50], [373, 56], [336, 57], [392, 109], [320, 115], [416, 170], [305, 176], [448, 225], [283, 234], [386, 229], [337, 232], [393, 324], [343, 324], [402, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0074.png, joints_for_superglue: [[354, 56], [363, 49], [347, 50], [375, 55], [337, 57], [394, 110], [321, 115], [417, 170], [306, 176], [449, 225], [284, 233], [388, 228], [338, 231], [393, 324], [343, 324], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0075.png, joints_for_superglue: [[355, 56], [364, 49], [349, 49], [376, 55], [339, 57], [395, 109], [322, 115], [418, 170], [307, 176], [450, 225], [285, 232], [389, 228], [339, 231], [394, 323], [344, 324], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0076.png, joints_for_superglue: [[357, 56], [366, 48], [350, 49], [378, 55], [341, 56], [396, 109], [324, 114], [419, 170], [308, 175], [451, 225], [286, 232], [389, 228], [340, 231], [394, 323], [344, 324], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0077.png, joints_for_superglue: [[364, 55], [373, 48], [356, 48], [383, 54], [347, 55], [401, 108], [329, 113], [424, 170], [313, 173], [456, 226], [289, 230], [394, 228], [345, 231], [398, 322], [346, 322], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0078.png, joints_for_superglue: [[365, 54], [374, 47], [358, 48], [386, 54], [348, 55], [403, 109], [330, 113], [425, 171], [313, 174], [457, 226], [290, 230], [395, 229], [346, 232], [400, 321], [347, 322], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0079.png, joints_for_superglue: [[367, 54], [376, 47], [360, 48], [387, 54], [350, 54], [405, 109], [331, 113], [427, 171], [314, 174], [458, 227], [291, 230], [396, 229], [347, 232], [400, 321], [347, 322], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0080.png, joints_for_superglue: [[369, 54], [378, 47], [362, 48], [389, 54], [352, 55], [407, 109], [333, 112], [428, 171], [316, 173], [460, 227], [293, 230], [398, 227], [349, 229], [402, 320], [348, 321], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0081.png, joints_for_superglue: [[371, 54], [380, 47], [364, 48], [391, 54], [353, 54], [408, 109], [334, 112], [430, 171], [317, 173], [461, 227], [294, 229], [399, 227], [350, 228], [403, 321], [349, 321], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205357_0082.png, joints_for_superglue: [[373, 54], [382, 47], [365, 48], [392, 54], [355, 54], [410, 109], [336, 112], [431, 170], [319, 173], [462, 227], [295, 229], [401, 226], [352, 227], [404, 321], [350, 322], [403, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0083.png, joints_for_superglue: [[379, 54], [387, 47], [371, 47], [398, 54], [360, 54], [416, 109], [341, 112], [435, 171], [323, 170], [466, 227], [298, 228], [405, 227], [356, 228], [406, 322], [352, 321], [404, 412], [344, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0084.png, joints_for_superglue: [[379, 53], [388, 46], [372, 47], [399, 54], [361, 54], [417, 109], [341, 111], [436, 170], [323, 170], [466, 227], [298, 228], [406, 227], [357, 228], [406, 322], [351, 320], [404, 412], [344, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0085.png, joints_for_superglue: [[379, 53], [388, 46], [373, 46], [400, 53], [362, 53], [417, 108], [342, 111], [436, 170], [324, 169], [466, 227], [298, 228], [407, 227], [358, 227], [406, 322], [351, 320], [404, 412], [343, 409]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0086.png, joints_for_superglue: [[380, 53], [388, 46], [373, 46], [400, 53], [362, 53], [418, 108], [343, 111], [436, 170], [323, 170], [466, 227], [298, 227], [406, 226], [357, 227], [407, 322], [350, 321], [404, 413], [342, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0087.png, joints_for_superglue: [[379, 53], [388, 45], [372, 46], [400, 53], [362, 53], [418, 108], [343, 111], [436, 169], [323, 170], [466, 227], [298, 227], [407, 226], [357, 227], [406, 322], [350, 321], [404, 412], [341, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0088.png, joints_for_superglue: [[377, 53], [386, 46], [370, 46], [397, 53], [359, 53], [415, 108], [341, 111], [434, 170], [321, 170], [465, 227], [296, 227], [406, 227], [356, 228], [406, 324], [348, 324], [404, 412], [340, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0089.png, joints_for_superglue: [[374, 53], [383, 46], [367, 47], [394, 54], [357, 54], [412, 108], [338, 112], [431, 171], [318, 170], [463, 227], [293, 228], [403, 227], [354, 227], [406, 324], [347, 326], [404, 412], [340, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0090.png, joints_for_superglue: [[373, 53], [381, 46], [365, 47], [392, 54], [355, 54], [410, 108], [336, 112], [430, 171], [316, 170], [461, 227], [291, 229], [402, 228], [353, 228], [405, 323], [347, 326], [404, 412], [340, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0091.png, joints_for_superglue: [[371, 54], [379, 47], [363, 47], [390, 54], [353, 54], [409, 109], [334, 112], [428, 171], [314, 171], [460, 226], [290, 229], [401, 228], [351, 228], [404, 322], [347, 326], [403, 412], [340, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0092.png, joints_for_superglue: [[368, 54], [377, 47], [361, 47], [388, 54], [350, 54], [406, 109], [332, 112], [426, 171], [313, 171], [457, 225], [287, 230], [399, 228], [350, 229], [404, 322], [346, 326], [403, 412], [340, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0093.png, joints_for_superglue: [[366, 54], [375, 47], [359, 47], [385, 54], [348, 55], [403, 109], [330, 112], [424, 171], [311, 171], [455, 226], [285, 231], [397, 228], [348, 230], [403, 322], [344, 327], [403, 412], [340, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0094.png, joints_for_superglue: [[364, 54], [372, 47], [356, 47], [382, 54], [346, 55], [401, 109], [328, 112], [421, 171], [308, 171], [453, 226], [284, 230], [396, 228], [346, 231], [401, 322], [343, 326], [403, 412], [339, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0095.png, joints_for_superglue: [[361, 54], [370, 47], [354, 47], [380, 54], [344, 55], [398, 108], [325, 112], [419, 171], [306, 171], [450, 225], [282, 230], [394, 229], [344, 231], [400, 322], [342, 327], [403, 412], [339, 412]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0096.png, joints_for_superglue: [[354, 54], [362, 47], [346, 48], [373, 54], [336, 56], [392, 110], [318, 113], [412, 171], [300, 172], [443, 225], [276, 231], [388, 230], [338, 232], [395, 323], [338, 329], [402, 412], [338, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0097.png, joints_for_superglue: [[352, 54], [360, 47], [344, 48], [370, 55], [334, 56], [390, 110], [316, 113], [410, 171], [298, 172], [442, 225], [274, 231], [386, 229], [336, 232], [393, 323], [338, 329], [402, 412], [338, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0098.png, joints_for_superglue: [[347, 55], [356, 47], [340, 48], [366, 55], [329, 57], [385, 110], [312, 113], [406, 172], [294, 173], [438, 225], [271, 233], [383, 229], [334, 232], [392, 324], [336, 331], [402, 412], [338, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam1\cam1_20241014_205358_0099.png, joints_for_superglue: [[345, 55], [353, 48], [338, 49], [364, 55], [327, 57], [383, 110], [310, 114], [404, 172], [292, 173], [436, 225], [269, 233], [381, 228], [332, 231], [391, 324], [335, 330], [401, 412], [338, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120234_0001.png, joints_for_superglue: [[424, 87], [429, 80], [416, 80], [400, 83], [444, 130], [383, 131], [463, 183], [367, 186], [492, 230], [344, 239], [443, 232], [401, 234], [444, 322], [403, 326], [448, 400], [407, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120234_0002.png, joints_for_superglue: [[423, 86], [429, 79], [416, 80], [400, 83], [445, 129], [383, 131], [464, 183], [367, 185], [492, 230], [344, 238], [443, 231], [400, 233], [444, 323], [403, 326], [448, 400], [407, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120235_0003.png, joints_for_superglue: [[420, 86], [425, 79], [412, 80], [397, 83], [442, 129], [381, 131], [463, 183], [364, 186], [491, 229], [341, 240], [442, 233], [398, 234], [443, 323], [402, 326], [449, 401], [407, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120235_0004.png, joints_for_superglue: [[416, 86], [422, 79], [409, 80], [393, 83], [440, 129], [378, 131], [461, 183], [362, 186], [490, 228], [340, 241], [440, 233], [396, 236], [443, 324], [400, 326], [449, 401], [407, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120235_0005.png, joints_for_superglue: [[412, 86], [418, 78], [405, 79], [424, 79], [391, 83], [439, 128], [376, 131], [461, 180], [361, 185], [491, 226], [339, 240], [438, 230], [394, 233], [445, 320], [399, 324], [454, 399], [406, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120235_0006.png, joints_for_superglue: [[418, 85], [424, 78], [410, 79], [432, 77], [398, 83], [449, 127], [385, 131], [471, 180], [367, 186], [503, 228], [343, 238], [444, 232], [400, 233], [451, 323], [402, 323], [458, 401], [406, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120235_0007.png, joints_for_superglue: [[421, 82], [427, 74], [412, 76], [437, 75], [402, 81], [457, 125], [391, 129], [480, 177], [372, 183], [511, 225], [346, 237], [449, 229], [403, 230], [452, 320], [404, 320], [458, 401], [406, 405]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120236_0008.png, joints_for_superglue: [[416, 83], [422, 75], [407, 77], [433, 76], [398, 83], [454, 125], [387, 131], [478, 179], [368, 186], [509, 226], [343, 237], [447, 231], [401, 232], [451, 321], [403, 323], [458, 402], [406, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120236_0009.png, joints_for_superglue: [[406, 82], [412, 74], [397, 77], [424, 76], [389, 82], [447, 124], [380, 131], [471, 177], [363, 186], [502, 227], [340, 238], [440, 233], [395, 235], [447, 319], [399, 323], [460, 402], [406, 408]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120236_0010.png, joints_for_superglue: [[410, 82], [417, 74], [403, 77], [432, 75], [397, 81], [458, 123], [390, 131], [482, 176], [373, 185], [514, 227], [347, 237], [445, 233], [401, 234], [452, 321], [401, 322], [460, 407], [406, 405]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120236_0011.png, joints_for_superglue: [[409, 81], [415, 73], [402, 76], [432, 74], [460, 122], [391, 131], [482, 176], [375, 185], [513, 228], [351, 237], [445, 234], [401, 236], [451, 319], [404, 323], [461, 406], [415, 405]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120237_0012.png, joints_for_superglue: [[400, 81], [406, 73], [393, 77], [423, 74], [452, 122], [385, 132], [476, 175], [371, 187], [508, 226], [349, 237], [438, 233], [397, 235], [446, 319], [402, 322], [461, 406], [413, 405]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120237_0013.png, joints_for_superglue: [[400, 81], [406, 72], [392, 76], [424, 73], [452, 121], [385, 131], [477, 174], [372, 186], [509, 224], [351, 237], [439, 236], [398, 236], [448, 320], [403, 323], [462, 409], [414, 405]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120237_0014.png, joints_for_superglue: [[405, 81], [412, 72], [398, 76], [430, 72], [460, 119], [394, 131], [483, 173], [379, 187], [513, 227], [356, 236], [446, 237], [403, 239], [453, 325], [405, 327], [462, 411], [415, 405]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120237_0015.png, joints_for_superglue: [[404, 81], [410, 72], [398, 76], [430, 71], [460, 117], [395, 130], [482, 172], [380, 187], [511, 226], [358, 236], [446, 237], [404, 239], [451, 326], [408, 326], [462, 411], [420, 406]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120237_0016.png, joints_for_superglue: [[395, 83], [401, 74], [389, 78], [420, 74], [451, 119], [389, 133], [474, 174], [376, 191], [503, 226], [357, 237], [437, 236], [399, 237], [446, 326], [405, 324], [461, 409], [419, 406]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120238_0017.png, joints_for_superglue: [[394, 82], [400, 74], [389, 78], [420, 73], [451, 118], [389, 132], [472, 171], [378, 189], [501, 225], [360, 236], [437, 237], [400, 239], [446, 327], [406, 326], [462, 412], [419, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120238_0018.png, joints_for_superglue: [[397, 82], [403, 73], [392, 78], [424, 72], [454, 117], [394, 131], [475, 173], [382, 188], [503, 228], [363, 235], [439, 238], [403, 238], [447, 328], [407, 326], [463, 413], [419, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120238_0019.png, joints_for_superglue: [[398, 82], [404, 73], [394, 78], [426, 70], [457, 113], [401, 129], [474, 170], [389, 188], [499, 228], [370, 234], [442, 242], [406, 240], [447, 326], [413, 324], [463, 416], [426, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20240912_120238_0020.png, joints_for_superglue: [[391, 84], [396, 75], [387, 79], [418, 72], [448, 115], [396, 131], [464, 173], [387, 189], [486, 227], [371, 235], [434, 243], [402, 243], [441, 324], [409, 323], [463, 414], [426, 407]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205353_0000.png, joints_for_superglue: [[288, 108], [295, 102], [281, 102], [300, 107], [269, 106], [314, 153], [252, 153], [327, 204], [239, 205], [339, 254], [224, 252], [305, 255], [262, 255], [312, 339], [263, 338], [320, 413], [260, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205353_0001.png, joints_for_superglue: [[288, 108], [295, 102], [281, 102], [300, 107], [269, 106], [313, 153], [252, 153], [327, 204], [239, 206], [339, 253], [224, 252], [305, 254], [262, 254], [311, 338], [263, 338], [320, 413], [259, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205353_0002.png, joints_for_superglue: [[289, 108], [295, 102], [282, 102], [300, 108], [269, 106], [313, 153], [251, 153], [327, 204], [239, 206], [339, 253], [223, 252], [305, 255], [262, 255], [311, 339], [263, 338], [320, 413], [259, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205354_0003.png, joints_for_superglue: [[289, 108], [295, 103], [282, 102], [300, 108], [269, 106], [313, 153], [251, 153], [327, 204], [238, 206], [339, 253], [223, 252], [305, 254], [262, 254], [311, 338], [263, 338], [320, 413], [259, 410]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205354_0004.png, joints_for_superglue: [[289, 108], [296, 103], [283, 102], [301, 108], [269, 106], [313, 153], [251, 153], [327, 204], [238, 206], [338, 253], [223, 252], [304, 254], [262, 254], [311, 338], [263, 338], [320, 414], [259, 411]]
# Image loaded successfully.
# Detected joints for 1 people.
# ...
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0051.png, joints_for_superglue: [[263, 107], [269, 102], [256, 101], [241, 105], [284, 154], [221, 150], [302, 205], [203, 203], [329, 249], [183, 253], [281, 255], [237, 257], [292, 336], [241, 341], [306, 411], [244, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0052.png, joints_for_superglue: [[261, 107], [267, 102], [254, 101], [239, 105], [282, 153], [220, 150], [301, 205], [201, 203], [328, 249], [182, 253], [280, 254], [236, 256], [292, 336], [240, 342], [306, 411], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0053.png, joints_for_superglue: [[260, 107], [266, 101], [253, 101], [238, 105], [281, 153], [218, 150], [300, 206], [199, 204], [327, 249], [181, 253], [279, 255], [235, 259], [291, 336], [239, 341], [305, 410], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0054.png, joints_for_superglue: [[255, 107], [261, 101], [248, 101], [233, 105], [277, 153], [214, 150], [296, 205], [196, 204], [323, 248], [178, 254], [276, 256], [232, 260], [290, 336], [238, 341], [305, 408], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0055.png, joints_for_superglue: [[254, 107], [260, 101], [248, 101], [233, 105], [276, 153], [213, 150], [296, 205], [195, 204], [323, 247], [177, 254], [275, 256], [232, 259], [289, 336], [238, 342], [304, 408], [243, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0056.png, joints_for_superglue: [[254, 107], [260, 101], [247, 100], [232, 104], [275, 153], [212, 150], [295, 205], [194, 204], [322, 247], [177, 254], [275, 256], [231, 260], [289, 336], [238, 343], [304, 408], [243, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0057.png, joints_for_superglue: [[253, 107], [260, 101], [247, 100], [232, 104], [275, 153], [212, 150], [295, 205], [194, 204], [322, 247], [176, 254], [275, 256], [230, 260], [289, 336], [238, 343], [303, 407], [243, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0058.png, joints_for_superglue: [[253, 107], [259, 101], [247, 100], [232, 104], [275, 153], [211, 150], [294, 204], [194, 204], [322, 247], [176, 254], [275, 256], [231, 260], [289, 336], [239, 344], [302, 407], [243, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0059.png, joints_for_superglue: [[254, 107], [260, 101], [248, 100], [232, 104], [275, 153], [211, 150], [294, 205], [194, 204], [322, 247], [177, 254], [276, 256], [232, 259], [289, 336], [239, 344], [299, 405], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0060.png, joints_for_superglue: [[255, 107], [261, 101], [248, 100], [232, 104], [275, 153], [212, 150], [294, 205], [194, 204], [322, 247], [178, 254], [277, 255], [232, 259], [288, 336], [239, 343], [298, 405], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0061.png, joints_for_superglue: [[255, 107], [261, 101], [248, 100], [233, 104], [275, 153], [212, 150], [294, 205], [195, 203], [322, 246], [179, 253], [277, 255], [233, 259], [288, 336], [240, 342], [297, 405], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205356_0062.png, joints_for_superglue: [[256, 107], [262, 101], [249, 100], [234, 104], [276, 153], [213, 150], [295, 205], [196, 202], [322, 246], [179, 253], [277, 255], [234, 259], [287, 335], [240, 341], [296, 406], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0063.png, joints_for_superglue: [[257, 107], [263, 102], [250, 100], [234, 104], [276, 153], [214, 149], [295, 205], [197, 202], [322, 246], [180, 253], [278, 255], [235, 258], [287, 335], [241, 341], [293, 406], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0064.png, joints_for_superglue: [[258, 107], [264, 102], [251, 101], [235, 104], [277, 153], [215, 150], [296, 205], [198, 203], [323, 247], [181, 253], [278, 254], [235, 257], [287, 335], [241, 341], [292, 407], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0065.png, joints_for_superglue: [[259, 107], [265, 102], [252, 101], [236, 104], [278, 153], [216, 150], [296, 206], [199, 203], [324, 247], [182, 253], [278, 253], [236, 256], [286, 335], [242, 340], [290, 407], [243, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0066.png, joints_for_superglue: [[264, 108], [270, 103], [257, 102], [242, 105], [282, 154], [221, 150], [300, 206], [205, 203], [326, 249], [188, 254], [281, 252], [241, 255], [286, 335], [243, 339], [290, 407], [244, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0067.png, joints_for_superglue: [[266, 108], [271, 103], [259, 102], [243, 105], [284, 155], [223, 150], [301, 206], [206, 202], [327, 249], [190, 253], [283, 252], [242, 255], [286, 335], [245, 340], [290, 407], [244, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0068.png, joints_for_superglue: [[267, 108], [273, 103], [260, 102], [245, 105], [285, 154], [224, 150], [301, 206], [208, 201], [328, 249], [192, 253], [284, 254], [243, 255], [287, 336], [245, 341], [290, 407], [244, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0069.png, joints_for_superglue: [[268, 108], [274, 103], [262, 102], [246, 105], [286, 154], [225, 150], [302, 207], [209, 201], [328, 249], [194, 252], [285, 254], [244, 255], [287, 337], [246, 341], [290, 407], [244, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0070.png, joints_for_superglue: [[270, 108], [275, 103], [263, 102], [248, 105], [287, 155], [226, 150], [303, 207], [211, 202], [329, 249], [196, 252], [286, 252], [246, 254], [288, 336], [247, 340], [290, 407], [244, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0071.png, joints_for_superglue: [[275, 109], [281, 104], [269, 102], [253, 105], [291, 155], [231, 150], [307, 208], [215, 201], [331, 250], [201, 252], [290, 252], [251, 255], [290, 336], [249, 340], [290, 407], [244, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0072.png, joints_for_superglue: [[277, 109], [283, 104], [271, 103], [254, 105], [292, 156], [232, 150], [307, 208], [217, 202], [332, 249], [202, 251], [290, 252], [251, 254], [290, 335], [250, 340], [290, 407], [244, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0073.png, joints_for_superglue: [[278, 109], [284, 104], [272, 103], [256, 105], [293, 156], [233, 150], [308, 208], [217, 202], [332, 250], [203, 250], [291, 253], [252, 254], [290, 335], [250, 339], [290, 407], [244, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0074.png, joints_for_superglue: [[279, 110], [284, 105], [273, 103], [256, 105], [294, 156], [235, 150], [308, 208], [218, 201], [333, 250], [205, 250], [292, 254], [253, 254], [291, 335], [251, 341], [290, 407], [244, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0075.png, joints_for_superglue: [[280, 110], [286, 105], [274, 103], [258, 105], [295, 156], [236, 150], [309, 209], [219, 201], [334, 251], [205, 249], [292, 254], [254, 255], [292, 335], [252, 342], [290, 407], [244, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0076.png, joints_for_superglue: [[281, 110], [287, 105], [275, 103], [259, 105], [296, 156], [237, 150], [310, 208], [220, 201], [334, 250], [206, 250], [293, 252], [254, 253], [292, 333], [253, 340], [290, 407], [244, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0077.png, joints_for_superglue: [[286, 110], [292, 105], [280, 103], [263, 105], [299, 156], [241, 150], [313, 209], [225, 201], [335, 251], [211, 249], [296, 252], [258, 254], [293, 333], [255, 338], [290, 407], [245, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0078.png, joints_for_superglue: [[287, 110], [293, 105], [281, 103], [265, 106], [300, 156], [242, 149], [313, 208], [226, 200], [336, 251], [212, 249], [297, 254], [259, 256], [294, 333], [256, 338], [290, 407], [245, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0079.png, joints_for_superglue: [[289, 110], [295, 106], [283, 104], [266, 106], [301, 156], [243, 150], [314, 209], [227, 200], [337, 251], [214, 248], [298, 253], [260, 255], [294, 333], [257, 339], [290, 406], [245, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0080.png, joints_for_superglue: [[290, 111], [296, 106], [284, 104], [268, 106], [302, 156], [245, 150], [315, 209], [229, 200], [338, 251], [215, 249], [299, 254], [261, 256], [295, 333], [257, 339], [290, 406], [245, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0081.png, joints_for_superglue: [[292, 111], [297, 106], [286, 104], [269, 106], [303, 157], [246, 150], [316, 209], [229, 200], [338, 251], [216, 249], [300, 254], [261, 256], [295, 333], [258, 339], [291, 406], [245, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205357_0082.png, joints_for_superglue: [[293, 111], [298, 106], [287, 105], [270, 106], [304, 157], [247, 150], [317, 210], [230, 200], [338, 251], [217, 248], [301, 256], [262, 257], [296, 334], [259, 339], [291, 406], [245, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0083.png, joints_for_superglue: [[294, 111], [299, 107], [288, 105], [271, 107], [305, 158], [248, 150], [317, 210], [231, 200], [339, 252], [218, 249], [301, 255], [263, 256], [296, 334], [259, 340], [291, 406], [245, 417]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0084.png, joints_for_superglue: [[297, 111], [302, 107], [290, 105], [274, 107], [308, 158], [252, 150], [319, 210], [234, 198], [340, 252], [220, 246], [304, 254], [265, 254], [297, 336], [260, 340], [291, 406], [245, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0085.png, joints_for_superglue: [[297, 111], [302, 106], [291, 105], [274, 107], [309, 158], [252, 150], [319, 210], [234, 199], [340, 252], [220, 246], [304, 255], [266, 255], [298, 335], [260, 341], [291, 406], [245, 413]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0086.png, joints_for_superglue: [[297, 111], [302, 106], [291, 104], [274, 107], [309, 157], [252, 150], [319, 210], [234, 199], [340, 252], [220, 246], [304, 254], [266, 255], [298, 335], [260, 339], [291, 406], [246, 412]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0087.png, joints_for_superglue: [[297, 111], [302, 106], [290, 104], [274, 107], [309, 157], [252, 150], [319, 209], [234, 199], [340, 252], [219, 246], [304, 254], [266, 254], [298, 335], [260, 339], [291, 406], [246, 412]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0088.png, joints_for_superglue: [[296, 111], [302, 106], [290, 104], [274, 107], [308, 157], [252, 150], [319, 210], [234, 199], [339, 252], [219, 246], [304, 253], [266, 254], [298, 335], [260, 339], [291, 406], [246, 413]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0089.png, joints_for_superglue: [[296, 111], [301, 106], [290, 104], [273, 107], [308, 157], [251, 150], [318, 210], [233, 199], [339, 251], [218, 247], [304, 254], [266, 255], [298, 335], [260, 339], [291, 406], [246, 413]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0090.png, joints_for_superglue: [[292, 110], [297, 106], [286, 104], [269, 106], [303, 156], [247, 150], [314, 209], [229, 200], [336, 251], [215, 248], [301, 255], [263, 256], [295, 336], [260, 340], [291, 406], [247, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0091.png, joints_for_superglue: [[290, 110], [295, 105], [284, 104], [267, 106], [301, 156], [245, 150], [313, 209], [228, 200], [335, 251], [214, 248], [300, 255], [263, 256], [295, 334], [260, 339], [290, 406], [247, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0092.png, joints_for_superglue: [[289, 110], [294, 105], [282, 103], [266, 106], [299, 156], [244, 150], [311, 209], [227, 200], [334, 251], [212, 249], [299, 255], [262, 256], [294, 336], [259, 340], [290, 406], [246, 413]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0093.png, joints_for_superglue: [[287, 109], [292, 105], [281, 103], [264, 106], [298, 156], [242, 149], [310, 209], [225, 199], [332, 250], [211, 248], [298, 255], [260, 256], [294, 335], [258, 339], [290, 406], [246, 413]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0094.png, joints_for_superglue: [[286, 109], [290, 104], [279, 102], [262, 105], [297, 156], [240, 149], [308, 208], [223, 200], [331, 250], [210, 249], [296, 251], [259, 254], [294, 334], [257, 339], [290, 406], [245, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0095.png, joints_for_superglue: [[284, 108], [289, 104], [277, 102], [260, 105], [295, 155], [239, 149], [306, 208], [222, 199], [329, 251], [208, 249], [295, 249], [257, 252], [293, 333], [257, 339], [290, 406], [246, 414]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0096.png, joints_for_superglue: [[277, 108], [282, 102], [271, 101], [253, 104], [288, 154], [232, 148], [300, 208], [216, 198], [322, 249], [203, 249], [290, 251], [252, 252], [292, 333], [251, 339], [290, 407], [245, 415]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0097.png, joints_for_superglue: [[276, 107], [280, 102], [269, 101], [252, 104], [286, 155], [230, 148], [298, 208], [215, 198], [320, 249], [202, 250], [289, 252], [250, 254], [291, 333], [250, 339], [290, 407], [244, 415]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0098.png, joints_for_superglue: [[274, 107], [279, 102], [268, 101], [250, 104], [285, 155], [229, 149], [296, 207], [214, 200], [319, 249], [201, 251], [287, 250], [248, 252], [291, 334], [249, 339], [290, 407], [244, 416]]
# Image loaded successfully.
# Detected joints for 1 people.
# image name: data\cam2\cam2_20241014_205358_0099.png, joints_for_superglue: [[273, 107], [278, 102], [266, 101], [249, 104], [284, 154], [228, 148], [295, 207], [212, 200], [318, 249], [200, 251], [286, 251], [248, 255], [290, 334], [248, 339], [290, 407], [244, 416]]
